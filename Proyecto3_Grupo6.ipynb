# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 2-3 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1: José Jesús La Casa Nieto
# *   Alumno 2:
# *   Alumno 3:

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/08_MIAR/actividades/proyecto practico"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())
# Out:
# Archivos en el directorio:
# ['checkpoint', 'dqn2_SpaceInvaders-v0_log.json', 'dqn2_SpaceInvaders-v0_weights.h5f.data-00000-of-00001', 'dqn2_SpaceInvaders-v0_weights.h5f.index', 'dqn2_SpaceInvaders-v0_weights_250000.h5f.data-00000-of-00001', 'dqn2_SpaceInvaders-v0_weights_250000.h5f.index', 'dqn2_SpaceInvaders-v0_weights_500000.h5f.data-00000-of-00001', 'dqn2_SpaceInvaders-v0_weights_500000.h5f.index', 'dqn3_SpaceInvaders-v0_log.json', 'dqn3_SpaceInvaders-v0_weights.h5f.data-00000-of-00001', 'dqn3_SpaceInvaders-v0_weights.h5f.index', 'dqn3_SpaceInvaders-v0_weights_250000.h5f.data-00000-of-00001', 'dqn3_SpaceInvaders-v0_weights_250000.h5f.index', 'dqn3_SpaceInvaders-v0_weights_500000.h5f.data-00000-of-00001', 'dqn3_SpaceInvaders-v0_weights_500000.h5f.index', 'dqn_SpaceInvaders-v0_log.json', 'dqn_SpaceInvaders-v0_weights.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights.h5f.index', 'dqn_SpaceInvaders-v0_weights_250000.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights_250000.h5f.index', 'dqn_SpaceInvaders-v0_weights_500000.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights_500000.h5f.index', 'Proyecto2_Grupo6.ipynb', 'Proyecto3_Grupo6.ipynb', 'Proyecto_Grupo6.ipynb', 'Proyecto_práctico.ipynb']

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install tensorflow==2.8
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.5.3
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN
# 3.   Justificar la respuesta en relación a los resultados obtenidos
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym
import os

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %%
print("Número de acciones disponibles: " + str(nb_actions))
# Out:
# Número de acciones disponibles: 6

# %%
print("Formato de observaciones:", env.observation_space)
# Out:
# Formato de observaciones: Box(0, 255, (210, 160, 3), uint8)

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()
print(K.image_data_format())

if K.image_data_format() == 'channels_last':
    model.add(Permute((2, 3, 1), input_shape=input_shape))
elif K.image_data_format() == 'channels_first':
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')

model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('linear'))
print(model.summary())
# Out:
# channels_last
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute (Permute)            (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 20, 20, 32)        8224
# _________________________________________________________________
# activation (Activation)      (None, 20, 20, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 9, 64)          32832
# _________________________________________________________________
# activation_1 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1606144
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 1542
# _________________________________________________________________
# activation_5 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 1,816,998
# Trainable params: 1,816,998
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# 2. Implementación de la solución DQN

# %%
memory = SequentialMemory(limit=100000, window_length=WINDOW_LENGTH)    # Reduzco un poco la memoria
processor = AtariProcessor()

# %%
policy = LinearAnnealedPolicy(
    EpsGreedyQPolicy(),
    attr='eps',
    value_max=1.,
    value_min=.1,
    value_test=.2,
    nb_steps=100000
)

# %%
dqn = DQNAgent(
    model=model,
    nb_actions=nb_actions,
    policy=policy,
    memory=memory,
    processor=processor,
    nb_steps_warmup=100000,   # Aumento el número de pasos iniciales porque el entorno es complejo y así obtiene una base sólida de experiencias
    gamma=.99,
    target_model_update=10000,  # Mantengo las mismas actualizaciones de las redes. Valores altos suponen mayor estabilidad pero más tiempo de entrenamiento
    train_interval=4,
    enable_dueling_network=True,
    dueling_type='avg'
)
dqn.compile(Adam(learning_rate=.00025), metrics=['mae'])

# %%
# Carga de los pesos del modelo anterior para reentrenarlos
weights_filename = 'dqn3_{}_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
results = dqn.test(env, nb_episodes=10, visualize=True)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 14.000, steps: 742
# Episode 2: reward: 14.000, steps: 551
# Episode 3: reward: 24.000, steps: 929
# Episode 4: reward: 17.000, steps: 600
# Episode 5: reward: 25.000, steps: 798
# Episode 6: reward: 19.000, steps: 673
# Episode 7: reward: 17.000, steps: 703
# Episode 8: reward: 26.000, steps: 940
# Episode 9: reward: 31.000, steps: 1016
# Episode 10: reward: 27.000, steps: 1012

# %%
# Cálculo de la media de las pruebas para ver los resultados previos al reentrenamiento
print(f"Average reward: {np.mean(results.history['episode_reward']):.1f}")
# Out:
# Average reward: 21.4

# %%
# Train
weights_filename = 'dqn3_{}_weights.h5f'.format(env_name)
checkpoint_weights_filename = 'dqn3_' + env_name + '_weights_{step}.h5f'
log_filename = 'dqn3_{}_log.json'.format(env_name)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
callbacks += [FileLogger(log_filename, interval=100)]

dqn.fit(
    env,
    callbacks=callbacks,
    nb_steps=500000,
    log_interval=1000,
    visualize=False
)

dqn.save_weights(weights_filename, overwrite=True)
# Out:
# Training for 500000 steps ...
# Interval 1 (0 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 2 episodes - episode_reward: 4.500 [3.000, 6.000] - ale.lives: 2.430
#
# Interval 2 (1000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0090
# 2 episodes - episode_reward: 7.500 [5.000, 10.000] - ale.lives: 2.001
#
# Interval 3 (2000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 1 episodes - episode_reward: 10.000 [10.000, 10.000] - ale.lives: 2.625
#
# Interval 4 (3000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0060
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 1.725
#
# Interval 5 (4000 steps performed)
# 1000/1000 [==============================] - 4s 4ms/step - reward: 0.0120
# 2 episodes - episode_reward: 7.000 [4.000, 10.000] - ale.lives: 1.866
#
# Interval 6 (5000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0140
# 1 episodes - episode_reward: 8.000 [8.000, 8.000] - ale.lives: 2.390
#
# Interval 7 (6000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0080
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 1.705
#
# Interval 8 (7000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0160
# 1 episodes - episode_reward: 7.000 [7.000, 7.000] - ale.lives: 2.096
#
# Interval 9 (8000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0160
# 2 episodes - episode_reward: 11.000 [10.000, 12.000] - ale.lives: 2.254
#
# Interval 10 (9000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0100
# 2 episodes - episode_reward: 7.000 [2.000, 12.000] - ale.lives: 2.176
#
# Interval 11 (10000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0170
# 1 episodes - episode_reward: 6.000 [6.000, 6.000] - ale.lives: 2.395
#
# Interval 12 (11000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0090
# 2 episodes - episode_reward: 10.000 [6.000, 14.000] - ale.lives: 1.783
#
# Interval 13 (12000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0140
# 1 episodes - episode_reward: 9.000 [9.000, 9.000] - ale.lives: 2.347
#
# Interval 14 (13000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0120
# 2 episodes - episode_reward: 8.500 [7.000, 10.000] - ale.lives: 1.903
#
# Interval 15 (14000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0120
# 1 episodes - episode_reward: 7.000 [7.000, 7.000] - ale.lives: 2.180
#
# Interval 16 (15000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0210
# 1 episodes - episode_reward: 6.000 [6.000, 6.000] - ale.lives: 2.260
#
# Interval 17 (16000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0120
# 2 episodes - episode_reward: 14.000 [4.000, 24.000] - ale.lives: 2.156
#
# Interval 18 (17000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - ale.lives: 2.166
#
# Interval 19 (18000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0180
# 2 episodes - episode_reward: 10.500 [9.000, 12.000] - ale.lives: 2.264
#
# Interval 20 (19000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0130
# 1 episodes - episode_reward: 9.000 [9.000, 9.000] - ale.lives: 2.343
#
# Interval 21 (20000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 2 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 1.952
#
# Interval 22 (21000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0270
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - ale.lives: 1.780
#
# Interval 23 (22000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - ale.lives: 2.154
#
# Interval 24 (23000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0160
# 2 episodes - episode_reward: 12.000 [9.000, 15.000] - ale.lives: 2.091
#
# Interval 25 (24000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0200
# 2 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 2.128
#
# Interval 26 (25000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0220
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - ale.lives: 2.154
#
# Interval 27 (26000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0200
# 2 episodes - episode_reward: 7.500 [6.000, 9.000] - ale.lives: 2.212
#
# Interval 28 (27000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0130
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - ale.lives: 1.833
#
# Interval 29 (28000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - ale.lives: 1.718
#
# Interval 30 (29000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 2 episodes - episode_reward: 10.500 [10.000, 11.000] - ale.lives: 2.197
#
# Interval 31 (30000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - ale.lives: 1.998
#
# Interval 32 (31000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0240
# 2 episodes - episode_reward: 14.000 [9.000, 19.000] - ale.lives: 2.293
#
# Interval 33 (32000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - ale.lives: 2.021
#
# Interval 34 (33000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0180
# 1 episodes - episode_reward: 8.000 [8.000, 8.000] - ale.lives: 1.927
#
# Interval 35 (34000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 2 episodes - episode_reward: 13.000 [10.000, 16.000] - ale.lives: 2.176
#
# Interval 36 (35000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0140
# 2 episodes - episode_reward: 9.500 [8.000, 11.000] - ale.lives: 1.853
#
# Interval 37 (36000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - ale.lives: 2.274
#
# Interval 38 (37000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0320
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - ale.lives: 2.036
#
# Interval 39 (38000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 1 episodes - episode_reward: 33.000 [33.000, 33.000] - ale.lives: 1.770
#
# Interval 40 (39000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - ale.lives: 1.745
#
# Interval 41 (40000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0170
# 2 episodes - episode_reward: 10.500 [10.000, 11.000] - ale.lives: 2.298
#
# Interval 42 (41000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0300
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - ale.lives: 2.250
#
# Interval 43 (42000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - ale.lives: 2.254
#
# Interval 44 (43000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0230
# 2 episodes - episode_reward: 12.000 [10.000, 14.000] - ale.lives: 2.091
#
# Interval 45 (44000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0220
# 2 episodes - episode_reward: 15.000 [10.000, 20.000] - ale.lives: 1.809
#
# Interval 46 (45000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 1 episodes - episode_reward: 5.000 [5.000, 5.000] - ale.lives: 2.140
#
# Interval 47 (46000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 2 episodes - episode_reward: 11.000 [10.000, 12.000] - ale.lives: 2.077
#
# Interval 48 (47000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0250
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - ale.lives: 2.156
#
# Interval 49 (48000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0220
# 2 episodes - episode_reward: 14.000 [9.000, 19.000] - ale.lives: 2.162
#
# Interval 50 (49000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0250
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 1.889
#
# Interval 51 (50000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 2 episodes - episode_reward: 18.500 [15.000, 22.000] - ale.lives: 2.070
#
# Interval 52 (51000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0180
# 2 episodes - episode_reward: 9.000 [4.000, 14.000] - ale.lives: 1.911
#
# Interval 53 (52000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0120
# 2 episodes - episode_reward: 6.000 [6.000, 6.000] - ale.lives: 1.851
#
# Interval 54 (53000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0280
# 1 episodes - episode_reward: 25.000 [25.000, 25.000] - ale.lives: 2.195
#
# Interval 55 (54000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0240
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 2.359
#
# Interval 56 (55000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0180
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - ale.lives: 1.456
#
# Interval 57 (56000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0250
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - ale.lives: 1.798
#
# Interval 58 (57000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0230
# 2 episodes - episode_reward: 12.000 [12.000, 12.000] - ale.lives: 1.928
#
# Interval 59 (58000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0260
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 1.649
#
# Interval 60 (59000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0160
# 2 episodes - episode_reward: 14.000 [7.000, 21.000] - ale.lives: 1.840
#
# Interval 61 (60000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 2 episodes - episode_reward: 8.000 [7.000, 9.000] - ale.lives: 2.464
#
# Interval 62 (61000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0300
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - ale.lives: 2.030
#
# Interval 63 (62000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0230
# 2 episodes - episode_reward: 19.500 [15.000, 24.000] - ale.lives: 2.385
#
# Interval 64 (63000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 2 episodes - episode_reward: 14.500 [12.000, 17.000] - ale.lives: 1.852
#
# Interval 65 (64000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0280
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - ale.lives: 2.087
#
# Interval 66 (65000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0230
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - ale.lives: 1.885
#
# Interval 67 (66000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0230
# 2 episodes - episode_reward: 10.000 [10.000, 10.000] - ale.lives: 2.447
#
# Interval 68 (67000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0250
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 1.809
#
# Interval 69 (68000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0250
# 2 episodes - episode_reward: 21.500 [20.000, 23.000] - ale.lives: 2.059
#
# Interval 70 (69000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0240
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - ale.lives: 1.650
#
# Interval 71 (70000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0280
# 1 episodes - episode_reward: 9.000 [9.000, 9.000] - ale.lives: 2.687
#
# Interval 72 (71000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 1 episodes - episode_reward: 31.000 [31.000, 31.000] - ale.lives: 1.912
#
# Interval 73 (72000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0290
# 2 episodes - episode_reward: 14.500 [13.000, 16.000] - ale.lives: 2.014
#
# Interval 74 (73000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 2.173
#
# Interval 75 (74000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 2 episodes - episode_reward: 16.000 [12.000, 20.000] - ale.lives: 2.025
#
# Interval 76 (75000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0270
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - ale.lives: 2.297
#
# Interval 77 (76000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0240
# 2 episodes - episode_reward: 17.500 [9.000, 26.000] - ale.lives: 1.702
#
# Interval 78 (77000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - ale.lives: 1.939
#
# Interval 79 (78000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0240
# 2 episodes - episode_reward: 14.000 [11.000, 17.000] - ale.lives: 1.652
#
# Interval 80 (79000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0240
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - ale.lives: 2.001
#
# Interval 81 (80000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0240
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - ale.lives: 2.441
#
# Interval 82 (81000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 2 episodes - episode_reward: 10.500 [9.000, 12.000] - ale.lives: 2.142
#
# Interval 83 (82000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0290
# 1 episodes - episode_reward: 30.000 [30.000, 30.000] - ale.lives: 2.252
#
# Interval 84 (83000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0220
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - ale.lives: 2.308
#
# Interval 85 (84000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0330
# 1 episodes - episode_reward: 29.000 [29.000, 29.000] - ale.lives: 1.799
#
# Interval 86 (85000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0270
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - ale.lives: 2.129
#
# Interval 87 (86000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0220
# 2 episodes - episode_reward: 21.000 [20.000, 22.000] - ale.lives: 2.213
#
# Interval 88 (87000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0240
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - ale.lives: 2.332
#
# Interval 89 (88000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 2 episodes - episode_reward: 12.000 [10.000, 14.000] - ale.lives: 2.003
#
# Interval 90 (89000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0260
# 2 episodes - episode_reward: 15.000 [6.000, 24.000] - ale.lives: 2.137
#
# Interval 91 (90000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0280
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - ale.lives: 2.608
#
# Interval 92 (91000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0300
# 1 episodes - episode_reward: 27.000 [27.000, 27.000] - ale.lives: 1.948
#
# Interval 93 (92000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0220
# 2 episodes - episode_reward: 13.000 [10.000, 16.000] - ale.lives: 2.371
#
# Interval 94 (93000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0240
# 1 episodes - episode_reward: 10.000 [10.000, 10.000] - ale.lives: 2.404
#
# Interval 95 (94000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 33.000 [33.000, 33.000] - ale.lives: 2.370
#
# Interval 96 (95000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0280
# 2 episodes - episode_reward: 18.000 [14.000, 22.000] - ale.lives: 1.953
#
# Interval 97 (96000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0220
# 1 episodes - episode_reward: 8.000 [8.000, 8.000] - ale.lives: 2.351
#
# Interval 98 (97000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0240
# 2 episodes - episode_reward: 16.000 [15.000, 17.000] - ale.lives: 2.122
#
# Interval 99 (98000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0270
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - ale.lives: 1.788
#
# Interval 100 (99000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0220
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 1.606
#
# Interval 101 (100000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0240
# 2 episodes - episode_reward: 18.500 [18.000, 19.000] - loss: 0.013 - mae: 0.964 - mean_q: 1.166 - mean_eps: 0.100 - ale.lives: 2.209
#
# Interval 102 (101000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0210
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.014 - mae: 0.973 - mean_q: 1.177 - mean_eps: 0.100 - ale.lives: 1.919
#
# Interval 103 (102000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0210
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.015 - mae: 0.980 - mean_q: 1.181 - mean_eps: 0.100 - ale.lives: 1.821
#
# Interval 104 (103000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0230
# 2 episodes - episode_reward: 17.500 [9.000, 26.000] - loss: 0.014 - mae: 0.986 - mean_q: 1.187 - mean_eps: 0.100 - ale.lives: 2.160
#
# Interval 105 (104000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0290
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - loss: 0.015 - mae: 0.985 - mean_q: 1.189 - mean_eps: 0.100 - ale.lives: 1.887
#
# Interval 106 (105000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0210
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.014 - mae: 0.987 - mean_q: 1.190 - mean_eps: 0.100 - ale.lives: 1.771
#
# Interval 107 (106000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0150
# 2 episodes - episode_reward: 13.000 [12.000, 14.000] - loss: 0.013 - mae: 0.992 - mean_q: 1.197 - mean_eps: 0.100 - ale.lives: 2.336
#
# Interval 108 (107000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0200
# 2 episodes - episode_reward: 11.500 [10.000, 13.000] - loss: 0.013 - mae: 0.988 - mean_q: 1.191 - mean_eps: 0.100 - ale.lives: 1.909
#
# Interval 109 (108000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0240
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.015 - mae: 1.006 - mean_q: 1.213 - mean_eps: 0.100 - ale.lives: 1.731
#
# Interval 110 (109000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0210
# 1 episodes - episode_reward: 8.000 [8.000, 8.000] - loss: 0.013 - mae: 0.995 - mean_q: 1.201 - mean_eps: 0.100 - ale.lives: 2.305
#
# Interval 111 (110000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 2 episodes - episode_reward: 20.000 [19.000, 21.000] - loss: 0.013 - mae: 1.005 - mean_q: 1.215 - mean_eps: 0.100 - ale.lives: 2.142
#
# Interval 112 (111000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0200
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - loss: 0.012 - mae: 1.006 - mean_q: 1.216 - mean_eps: 0.100 - ale.lives: 2.119
#
# Interval 113 (112000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0230
# 1 episodes - episode_reward: 5.000 [5.000, 5.000] - loss: 0.012 - mae: 1.008 - mean_q: 1.217 - mean_eps: 0.100 - ale.lives: 2.417
#
# Interval 114 (113000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0150
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.012 - mae: 1.003 - mean_q: 1.210 - mean_eps: 0.100 - ale.lives: 1.778
#
# Interval 115 (114000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0290
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.013 - mae: 1.011 - mean_q: 1.221 - mean_eps: 0.100 - ale.lives: 1.991
#
# Interval 116 (115000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0240
# 2 episodes - episode_reward: 23.500 [19.000, 28.000] - loss: 0.013 - mae: 1.011 - mean_q: 1.220 - mean_eps: 0.100 - ale.lives: 2.192
#
# Interval 117 (116000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 1 episodes - episode_reward: 25.000 [25.000, 25.000] - loss: 0.011 - mae: 1.011 - mean_q: 1.219 - mean_eps: 0.100 - ale.lives: 1.651
#
# Interval 118 (117000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0260
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.012 - mae: 1.028 - mean_q: 1.242 - mean_eps: 0.100 - ale.lives: 1.950
#
# Interval 119 (118000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0170
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - loss: 0.012 - mae: 1.025 - mean_q: 1.237 - mean_eps: 0.100 - ale.lives: 1.971
#
# Interval 120 (119000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0210
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.013 - mae: 1.025 - mean_q: 1.236 - mean_eps: 0.100 - ale.lives: 2.112
#
# Interval 121 (120000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0240
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - loss: 0.011 - mae: 1.057 - mean_q: 1.276 - mean_eps: 0.100 - ale.lives: 1.897
#
# Interval 122 (121000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0240
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - loss: 0.011 - mae: 1.054 - mean_q: 1.272 - mean_eps: 0.100 - ale.lives: 1.839
#
# Interval 123 (122000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0160
# 2 episodes - episode_reward: 13.000 [8.000, 18.000] - loss: 0.012 - mae: 1.052 - mean_q: 1.269 - mean_eps: 0.100 - ale.lives: 2.072
#
# Interval 124 (123000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0250
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.011 - mae: 1.056 - mean_q: 1.274 - mean_eps: 0.100 - ale.lives: 1.675
#
# Interval 125 (124000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0210
# 2 episodes - episode_reward: 16.000 [13.000, 19.000] - loss: 0.011 - mae: 1.051 - mean_q: 1.269 - mean_eps: 0.100 - ale.lives: 2.462
#
# Interval 126 (125000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0150
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.011 - mae: 1.055 - mean_q: 1.274 - mean_eps: 0.100 - ale.lives: 1.840
#
# Interval 127 (126000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0180
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - loss: 0.010 - mae: 1.062 - mean_q: 1.281 - mean_eps: 0.100 - ale.lives: 2.105
#
# Interval 128 (127000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0160
# 2 episodes - episode_reward: 10.500 [8.000, 13.000] - loss: 0.012 - mae: 1.064 - mean_q: 1.284 - mean_eps: 0.100 - ale.lives: 2.289
#
# Interval 129 (128000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0210
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.010 - mae: 1.057 - mean_q: 1.276 - mean_eps: 0.100 - ale.lives: 2.346
#
# Interval 130 (129000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0260
# 2 episodes - episode_reward: 15.000 [14.000, 16.000] - loss: 0.011 - mae: 1.060 - mean_q: 1.281 - mean_eps: 0.100 - ale.lives: 1.907
#
# Interval 131 (130000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0200
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.011 - mae: 1.069 - mean_q: 1.291 - mean_eps: 0.100 - ale.lives: 2.317
#
# Interval 132 (131000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0200
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.011 - mae: 1.059 - mean_q: 1.280 - mean_eps: 0.100 - ale.lives: 2.008
#
# Interval 133 (132000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0180
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.011 - mae: 1.064 - mean_q: 1.286 - mean_eps: 0.100 - ale.lives: 2.119
#
# Interval 134 (133000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0160
# 2 episodes - episode_reward: 15.000 [12.000, 18.000] - loss: 0.011 - mae: 1.064 - mean_q: 1.284 - mean_eps: 0.100 - ale.lives: 2.064
#
# Interval 135 (134000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0190
# 1 episodes - episode_reward: 7.000 [7.000, 7.000] - loss: 0.011 - mae: 1.063 - mean_q: 1.282 - mean_eps: 0.100 - ale.lives: 2.151
#
# Interval 136 (135000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0230
# 2 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.011 - mae: 1.066 - mean_q: 1.287 - mean_eps: 0.100 - ale.lives: 1.875
#
# Interval 137 (136000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0110
# 2 episodes - episode_reward: 7.000 [6.000, 8.000] - loss: 0.009 - mae: 1.066 - mean_q: 1.287 - mean_eps: 0.100 - ale.lives: 2.091
#
# Interval 138 (137000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0200
# 2 episodes - episode_reward: 9.500 [4.000, 15.000] - loss: 0.010 - mae: 1.063 - mean_q: 1.283 - mean_eps: 0.100 - ale.lives: 1.969
#
# Interval 139 (138000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0220
# 2 episodes - episode_reward: 11.500 [8.000, 15.000] - loss: 0.011 - mae: 1.073 - mean_q: 1.297 - mean_eps: 0.100 - ale.lives: 1.986
#
# Interval 140 (139000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0240
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - loss: 0.010 - mae: 1.062 - mean_q: 1.283 - mean_eps: 0.100 - ale.lives: 2.197
#
# Interval 141 (140000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0200
# 2 episodes - episode_reward: 10.500 [10.000, 11.000] - loss: 0.010 - mae: 1.096 - mean_q: 1.325 - mean_eps: 0.100 - ale.lives: 2.053
#
# Interval 142 (141000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0300
# Interval 143 (142000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0170
# 2 episodes - episode_reward: 25.000 [15.000, 35.000] - loss: 0.010 - mae: 1.093 - mean_q: 1.319 - mean_eps: 0.100 - ale.lives: 2.123
#
# Interval 144 (143000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0240
# 2 episodes - episode_reward: 11.000 [10.000, 12.000] - loss: 0.010 - mae: 1.092 - mean_q: 1.318 - mean_eps: 0.100 - ale.lives: 2.054
#
# Interval 145 (144000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0270
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.010 - mae: 1.103 - mean_q: 1.333 - mean_eps: 0.100 - ale.lives: 2.135
#
# Interval 146 (145000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0230
# 3 episodes - episode_reward: 9.000 [7.000, 12.000] - loss: 0.010 - mae: 1.099 - mean_q: 1.328 - mean_eps: 0.100 - ale.lives: 2.243
#
# Interval 147 (146000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0200
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.010 - mae: 1.098 - mean_q: 1.327 - mean_eps: 0.100 - ale.lives: 1.850
#
# Interval 148 (147000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0170
# 2 episodes - episode_reward: 13.500 [10.000, 17.000] - loss: 0.010 - mae: 1.086 - mean_q: 1.311 - mean_eps: 0.100 - ale.lives: 1.650
#
# Interval 149 (148000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0260
# 1 episodes - episode_reward: 26.000 [26.000, 26.000] - loss: 0.011 - mae: 1.104 - mean_q: 1.335 - mean_eps: 0.100 - ale.lives: 1.546
#
# Interval 150 (149000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0190
# 2 episodes - episode_reward: 9.500 [9.000, 10.000] - loss: 0.010 - mae: 1.108 - mean_q: 1.339 - mean_eps: 0.100 - ale.lives: 1.998
#
# Interval 151 (150000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0220
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.010 - mae: 1.124 - mean_q: 1.358 - mean_eps: 0.100 - ale.lives: 2.229
#
# Interval 152 (151000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0180
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.010 - mae: 1.136 - mean_q: 1.370 - mean_eps: 0.100 - ale.lives: 2.287
#
# Interval 153 (152000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0280
# 1 episodes - episode_reward: 27.000 [27.000, 27.000] - loss: 0.011 - mae: 1.136 - mean_q: 1.372 - mean_eps: 0.100 - ale.lives: 2.086
#
# Interval 154 (153000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0220
# 1 episodes - episode_reward: 25.000 [25.000, 25.000] - loss: 0.010 - mae: 1.138 - mean_q: 1.373 - mean_eps: 0.100 - ale.lives: 2.160
#
# Interval 155 (154000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0190
# 1 episodes - episode_reward: 4.000 [4.000, 4.000] - loss: 0.010 - mae: 1.132 - mean_q: 1.366 - mean_eps: 0.100 - ale.lives: 2.063
#
# Interval 156 (155000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0170
# 2 episodes - episode_reward: 11.000 [6.000, 16.000] - loss: 0.008 - mae: 1.121 - mean_q: 1.353 - mean_eps: 0.100 - ale.lives: 2.030
#
# Interval 157 (156000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 2 episodes - episode_reward: 14.000 [13.000, 15.000] - loss: 0.010 - mae: 1.129 - mean_q: 1.364 - mean_eps: 0.100 - ale.lives: 2.311
#
# Interval 158 (157000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0270
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - loss: 0.009 - mae: 1.135 - mean_q: 1.370 - mean_eps: 0.100 - ale.lives: 2.098
#
# Interval 159 (158000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0200
# 1 episodes - episode_reward: 33.000 [33.000, 33.000] - loss: 0.010 - mae: 1.136 - mean_q: 1.371 - mean_eps: 0.100 - ale.lives: 2.212
#
# Interval 160 (159000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0200
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - loss: 0.010 - mae: 1.138 - mean_q: 1.374 - mean_eps: 0.100 - ale.lives: 1.561
#
# Interval 161 (160000 steps performed)
# 1000/1000 [==============================] - 20s 19ms/step - reward: 0.0250
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - loss: 0.011 - mae: 1.163 - mean_q: 1.406 - mean_eps: 0.100 - ale.lives: 2.170
#
# Interval 162 (161000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0210
# 1 episodes - episode_reward: 27.000 [27.000, 27.000] - loss: 0.010 - mae: 1.168 - mean_q: 1.412 - mean_eps: 0.100 - ale.lives: 2.387
#
# Interval 163 (162000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 2 episodes - episode_reward: 9.500 [6.000, 13.000] - loss: 0.010 - mae: 1.179 - mean_q: 1.426 - mean_eps: 0.100 - ale.lives: 2.095
#
# Interval 164 (163000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 2 episodes - episode_reward: 11.000 [9.000, 13.000] - loss: 0.009 - mae: 1.166 - mean_q: 1.411 - mean_eps: 0.100 - ale.lives: 2.082
#
# Interval 165 (164000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0220
# 1 episodes - episode_reward: 31.000 [31.000, 31.000] - loss: 0.010 - mae: 1.161 - mean_q: 1.405 - mean_eps: 0.100 - ale.lives: 1.883
#
# Interval 166 (165000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0200
# 1 episodes - episode_reward: 7.000 [7.000, 7.000] - loss: 0.010 - mae: 1.178 - mean_q: 1.424 - mean_eps: 0.100 - ale.lives: 2.333
#
# Interval 167 (166000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0280
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - loss: 0.009 - mae: 1.173 - mean_q: 1.419 - mean_eps: 0.100 - ale.lives: 1.912
#
# Interval 168 (167000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0190
# 2 episodes - episode_reward: 15.000 [8.000, 22.000] - loss: 0.010 - mae: 1.186 - mean_q: 1.433 - mean_eps: 0.100 - ale.lives: 2.119
#
# Interval 169 (168000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0170
# 2 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.009 - mae: 1.172 - mean_q: 1.416 - mean_eps: 0.100 - ale.lives: 1.998
#
# Interval 170 (169000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0220
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.009 - mae: 1.162 - mean_q: 1.404 - mean_eps: 0.100 - ale.lives: 2.437
#
# Interval 171 (170000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0130
# 2 episodes - episode_reward: 7.000 [7.000, 7.000] - loss: 0.011 - mae: 1.187 - mean_q: 1.435 - mean_eps: 0.100 - ale.lives: 2.126
#
# Interval 172 (171000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0290
# 1 episodes - episode_reward: 10.000 [10.000, 10.000] - loss: 0.010 - mae: 1.190 - mean_q: 1.438 - mean_eps: 0.100 - ale.lives: 2.262
#
# Interval 173 (172000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0220
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - loss: 0.009 - mae: 1.192 - mean_q: 1.443 - mean_eps: 0.100 - ale.lives: 2.226
#
# Interval 174 (173000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0220
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.009 - mae: 1.189 - mean_q: 1.438 - mean_eps: 0.100 - ale.lives: 2.424
#
# Interval 175 (174000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0180
# 2 episodes - episode_reward: 17.500 [15.000, 20.000] - loss: 0.010 - mae: 1.199 - mean_q: 1.451 - mean_eps: 0.100 - ale.lives: 2.149
#
# Interval 176 (175000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0130
# 2 episodes - episode_reward: 6.000 [4.000, 8.000] - loss: 0.010 - mae: 1.194 - mean_q: 1.443 - mean_eps: 0.100 - ale.lives: 1.925
#
# Interval 177 (176000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0310
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.010 - mae: 1.187 - mean_q: 1.433 - mean_eps: 0.100 - ale.lives: 2.139
#
# Interval 178 (177000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0140
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.009 - mae: 1.189 - mean_q: 1.436 - mean_eps: 0.100 - ale.lives: 1.968
#
# Interval 179 (178000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0180
# 2 episodes - episode_reward: 10.500 [9.000, 12.000] - loss: 0.009 - mae: 1.184 - mean_q: 1.430 - mean_eps: 0.100 - ale.lives: 1.940
#
# Interval 180 (179000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.010 - mae: 1.194 - mean_q: 1.443 - mean_eps: 0.100 - ale.lives: 1.852
#
# Interval 181 (180000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0240
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - loss: 0.010 - mae: 1.224 - mean_q: 1.480 - mean_eps: 0.100 - ale.lives: 1.808
#
# Interval 182 (181000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0230
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.011 - mae: 1.228 - mean_q: 1.484 - mean_eps: 0.100 - ale.lives: 1.613
#
# Interval 183 (182000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0180
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.010 - mae: 1.221 - mean_q: 1.477 - mean_eps: 0.100 - ale.lives: 2.063
#
# Interval 184 (183000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0170
# 2 episodes - episode_reward: 10.000 [8.000, 12.000] - loss: 0.009 - mae: 1.226 - mean_q: 1.481 - mean_eps: 0.100 - ale.lives: 2.161
#
# Interval 185 (184000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0230
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - loss: 0.010 - mae: 1.226 - mean_q: 1.481 - mean_eps: 0.100 - ale.lives: 2.261
#
# Interval 186 (185000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0130
# 2 episodes - episode_reward: 13.500 [7.000, 20.000] - loss: 0.011 - mae: 1.238 - mean_q: 1.495 - mean_eps: 0.100 - ale.lives: 2.035
#
# Interval 187 (186000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0200
# 2 episodes - episode_reward: 11.500 [11.000, 12.000] - loss: 0.010 - mae: 1.228 - mean_q: 1.483 - mean_eps: 0.100 - ale.lives: 1.566
#
# Interval 188 (187000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0250
# Interval 189 (188000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0230
# 2 episodes - episode_reward: 18.000 [10.000, 26.000] - loss: 0.010 - mae: 1.238 - mean_q: 1.495 - mean_eps: 0.100 - ale.lives: 2.109
#
# Interval 190 (189000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 2 episodes - episode_reward: 18.500 [16.000, 21.000] - loss: 0.009 - mae: 1.233 - mean_q: 1.489 - mean_eps: 0.100 - ale.lives: 1.663
#
# Interval 191 (190000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0190
# 1 episodes - episode_reward: 5.000 [5.000, 5.000] - loss: 0.010 - mae: 1.222 - mean_q: 1.478 - mean_eps: 0.100 - ale.lives: 2.375
#
# Interval 192 (191000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0190
# 2 episodes - episode_reward: 11.000 [8.000, 14.000] - loss: 0.011 - mae: 1.219 - mean_q: 1.474 - mean_eps: 0.100 - ale.lives: 2.433
#
# Interval 193 (192000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0250
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.009 - mae: 1.220 - mean_q: 1.476 - mean_eps: 0.100 - ale.lives: 2.112
#
# Interval 194 (193000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0190
# 1 episodes - episode_reward: 31.000 [31.000, 31.000] - loss: 0.010 - mae: 1.229 - mean_q: 1.486 - mean_eps: 0.100 - ale.lives: 1.931
#
# Interval 195 (194000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0190
# 1 episodes - episode_reward: 10.000 [10.000, 10.000] - loss: 0.010 - mae: 1.226 - mean_q: 1.481 - mean_eps: 0.100 - ale.lives: 2.292
#
# Interval 196 (195000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0210
# 2 episodes - episode_reward: 15.500 [13.000, 18.000] - loss: 0.010 - mae: 1.217 - mean_q: 1.471 - mean_eps: 0.100 - ale.lives: 2.091
#
# Interval 197 (196000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 1 episodes - episode_reward: 27.000 [27.000, 27.000] - loss: 0.011 - mae: 1.226 - mean_q: 1.481 - mean_eps: 0.100 - ale.lives: 2.478
#
# Interval 198 (197000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0200
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.009 - mae: 1.222 - mean_q: 1.477 - mean_eps: 0.100 - ale.lives: 2.079
#
# Interval 199 (198000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0230
# 2 episodes - episode_reward: 14.500 [10.000, 19.000] - loss: 0.010 - mae: 1.229 - mean_q: 1.485 - mean_eps: 0.100 - ale.lives: 1.932
#
# Interval 200 (199000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0090
# 1 episodes - episode_reward: 8.000 [8.000, 8.000] - loss: 0.009 - mae: 1.220 - mean_q: 1.474 - mean_eps: 0.100 - ale.lives: 2.162
#
# Interval 201 (200000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0260
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.009 - mae: 1.243 - mean_q: 1.504 - mean_eps: 0.100 - ale.lives: 1.699
#
# Interval 202 (201000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0210
# 2 episodes - episode_reward: 16.500 [16.000, 17.000] - loss: 0.010 - mae: 1.245 - mean_q: 1.504 - mean_eps: 0.100 - ale.lives: 2.213
#
# Interval 203 (202000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0220
# 2 episodes - episode_reward: 11.500 [5.000, 18.000] - loss: 0.010 - mae: 1.239 - mean_q: 1.497 - mean_eps: 0.100 - ale.lives: 2.390
#
# Interval 204 (203000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0130
# 2 episodes - episode_reward: 7.500 [6.000, 9.000] - loss: 0.009 - mae: 1.226 - mean_q: 1.483 - mean_eps: 0.100 - ale.lives: 1.956
#
# Interval 205 (204000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0280
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - loss: 0.010 - mae: 1.238 - mean_q: 1.495 - mean_eps: 0.100 - ale.lives: 2.055
#
# Interval 206 (205000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0200
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.009 - mae: 1.235 - mean_q: 1.492 - mean_eps: 0.100 - ale.lives: 2.086
#
# Interval 207 (206000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0210
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - loss: 0.009 - mae: 1.226 - mean_q: 1.481 - mean_eps: 0.100 - ale.lives: 1.711
#
# Interval 208 (207000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0300
# 2 episodes - episode_reward: 23.500 [23.000, 24.000] - loss: 0.009 - mae: 1.227 - mean_q: 1.482 - mean_eps: 0.100 - ale.lives: 1.929
#
# Interval 209 (208000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0170
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.009 - mae: 1.231 - mean_q: 1.487 - mean_eps: 0.100 - ale.lives: 2.336
#
# Interval 210 (209000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0260
# 2 episodes - episode_reward: 16.500 [13.000, 20.000] - loss: 0.009 - mae: 1.231 - mean_q: 1.488 - mean_eps: 0.100 - ale.lives: 1.685
#
# Interval 211 (210000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.010 - mae: 1.245 - mean_q: 1.505 - mean_eps: 0.100 - ale.lives: 2.312
#
# Interval 212 (211000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0250
# 1 episodes - episode_reward: 29.000 [29.000, 29.000] - loss: 0.009 - mae: 1.241 - mean_q: 1.500 - mean_eps: 0.100 - ale.lives: 1.454
#
# Interval 213 (212000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0250
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - loss: 0.010 - mae: 1.243 - mean_q: 1.502 - mean_eps: 0.100 - ale.lives: 1.915
#
# Interval 214 (213000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0300
# 1 episodes - episode_reward: 27.000 [27.000, 27.000] - loss: 0.010 - mae: 1.249 - mean_q: 1.509 - mean_eps: 0.100 - ale.lives: 2.341
#
# Interval 215 (214000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0250
# 2 episodes - episode_reward: 12.000 [7.000, 17.000] - loss: 0.009 - mae: 1.253 - mean_q: 1.515 - mean_eps: 0.100 - ale.lives: 2.287
#
# Interval 216 (215000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0250
# 1 episodes - episode_reward: 25.000 [25.000, 25.000] - loss: 0.010 - mae: 1.250 - mean_q: 1.508 - mean_eps: 0.100 - ale.lives: 2.327
#
# Interval 217 (216000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0170
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - loss: 0.010 - mae: 1.237 - mean_q: 1.494 - mean_eps: 0.100 - ale.lives: 2.015
#
# Interval 218 (217000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0230
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.010 - mae: 1.243 - mean_q: 1.500 - mean_eps: 0.100 - ale.lives: 1.937
#
# Interval 219 (218000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0200
# 2 episodes - episode_reward: 13.500 [13.000, 14.000] - loss: 0.009 - mae: 1.246 - mean_q: 1.505 - mean_eps: 0.100 - ale.lives: 1.785
#
# Interval 220 (219000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0270
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.010 - mae: 1.246 - mean_q: 1.505 - mean_eps: 0.100 - ale.lives: 2.530
#
# Interval 221 (220000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0210
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - loss: 0.010 - mae: 1.259 - mean_q: 1.521 - mean_eps: 0.100 - ale.lives: 2.714
#
# Interval 222 (221000 steps performed)
# ...
# 2 episodes - episode_reward: 10.500 [7.000, 14.000] - loss: 0.012 - mae: 1.627 - mean_q: 1.962 - mean_eps: 0.100 - ale.lives: 2.354
#
# Interval 434 (433000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0250
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.011 - mae: 1.629 - mean_q: 1.963 - mean_eps: 0.100 - ale.lives: 2.355
#
# Interval 435 (434000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0210
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - loss: 0.011 - mae: 1.630 - mean_q: 1.966 - mean_eps: 0.100 - ale.lives: 2.071
#
# Interval 436 (435000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0200
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - loss: 0.011 - mae: 1.622 - mean_q: 1.956 - mean_eps: 0.100 - ale.lives: 1.933
#
# Interval 437 (436000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0280
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.010 - mae: 1.640 - mean_q: 1.980 - mean_eps: 0.100 - ale.lives: 2.249
#
# Interval 438 (437000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0180
# 2 episodes - episode_reward: 16.000 [11.000, 21.000] - loss: 0.010 - mae: 1.615 - mean_q: 1.950 - mean_eps: 0.100 - ale.lives: 2.080
#
# Interval 439 (438000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0190
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.011 - mae: 1.643 - mean_q: 1.981 - mean_eps: 0.100 - ale.lives: 2.290
#
# Interval 440 (439000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0180
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.012 - mae: 1.627 - mean_q: 1.963 - mean_eps: 0.100 - ale.lives: 2.168
#
# Interval 441 (440000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0190
# 2 episodes - episode_reward: 15.500 [13.000, 18.000] - loss: 0.010 - mae: 1.644 - mean_q: 1.986 - mean_eps: 0.100 - ale.lives: 1.989
#
# Interval 442 (441000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0310
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.010 - mae: 1.633 - mean_q: 1.971 - mean_eps: 0.100 - ale.lives: 1.642
#
# Interval 443 (442000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0170
# 2 episodes - episode_reward: 10.500 [5.000, 16.000] - loss: 0.011 - mae: 1.644 - mean_q: 1.984 - mean_eps: 0.100 - ale.lives: 2.028
#
# Interval 444 (443000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0170
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.011 - mae: 1.652 - mean_q: 1.995 - mean_eps: 0.100 - ale.lives: 1.395
#
# Interval 445 (444000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0300
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.012 - mae: 1.634 - mean_q: 1.973 - mean_eps: 0.100 - ale.lives: 1.899
#
# Interval 446 (445000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0240
# 2 episodes - episode_reward: 12.500 [6.000, 19.000] - loss: 0.011 - mae: 1.640 - mean_q: 1.977 - mean_eps: 0.100 - ale.lives: 2.147
#
# Interval 447 (446000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0230
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - loss: 0.011 - mae: 1.652 - mean_q: 1.993 - mean_eps: 0.100 - ale.lives: 1.901
#
# Interval 448 (447000 steps performed)
# 1000/1000 [==============================] - 21s 20ms/step - reward: 0.0250
# 2 episodes - episode_reward: 20.000 [17.000, 23.000] - loss: 0.010 - mae: 1.646 - mean_q: 1.985 - mean_eps: 0.100 - ale.lives: 2.479
#
# Interval 449 (448000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0200
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.011 - mae: 1.640 - mean_q: 1.978 - mean_eps: 0.100 - ale.lives: 2.298
#
# Interval 450 (449000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0170
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.011 - mae: 1.636 - mean_q: 1.973 - mean_eps: 0.100 - ale.lives: 2.091
#
# Interval 451 (450000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0210
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - loss: 0.011 - mae: 1.661 - mean_q: 2.005 - mean_eps: 0.100 - ale.lives: 1.973
#
# Interval 452 (451000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0190
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - loss: 0.011 - mae: 1.660 - mean_q: 2.003 - mean_eps: 0.100 - ale.lives: 2.004
#
# Interval 453 (452000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0170
# 1 episodes - episode_reward: 9.000 [9.000, 9.000] - loss: 0.011 - mae: 1.644 - mean_q: 1.985 - mean_eps: 0.100 - ale.lives: 2.116
#
# Interval 454 (453000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0190
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - loss: 0.012 - mae: 1.659 - mean_q: 2.002 - mean_eps: 0.100 - ale.lives: 2.098
#
# Interval 455 (454000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0210
# 1 episodes - episode_reward: 29.000 [29.000, 29.000] - loss: 0.012 - mae: 1.637 - mean_q: 1.975 - mean_eps: 0.100 - ale.lives: 1.359
#
# Interval 456 (455000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0310
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - loss: 0.012 - mae: 1.660 - mean_q: 2.002 - mean_eps: 0.100 - ale.lives: 2.336
#
# Interval 457 (456000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0180
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.011 - mae: 1.656 - mean_q: 1.997 - mean_eps: 0.100 - ale.lives: 1.624
#
# Interval 458 (457000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0280
# 1 episodes - episode_reward: 8.000 [8.000, 8.000] - loss: 0.010 - mae: 1.641 - mean_q: 1.979 - mean_eps: 0.100 - ale.lives: 1.844
#
# Interval 459 (458000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0260
# 2 episodes - episode_reward: 22.500 [16.000, 29.000] - loss: 0.011 - mae: 1.645 - mean_q: 1.984 - mean_eps: 0.100 - ale.lives: 1.860
#
# Interval 460 (459000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0180
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.012 - mae: 1.650 - mean_q: 1.991 - mean_eps: 0.100 - ale.lives: 2.148
#
# Interval 461 (460000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0250
# 2 episodes - episode_reward: 18.500 [16.000, 21.000] - loss: 0.011 - mae: 1.659 - mean_q: 2.002 - mean_eps: 0.100 - ale.lives: 2.119
#
# Interval 462 (461000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0280
# 1 episodes - episode_reward: 10.000 [10.000, 10.000] - loss: 0.011 - mae: 1.661 - mean_q: 2.002 - mean_eps: 0.100 - ale.lives: 2.178
#
# Interval 463 (462000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 2 episodes - episode_reward: 16.500 [8.000, 25.000] - loss: 0.010 - mae: 1.652 - mean_q: 1.993 - mean_eps: 0.100 - ale.lives: 1.794
#
# Interval 464 (463000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0220
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.012 - mae: 1.668 - mean_q: 2.011 - mean_eps: 0.100 - ale.lives: 2.374
#
# Interval 465 (464000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0200
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.011 - mae: 1.662 - mean_q: 2.003 - mean_eps: 0.100 - ale.lives: 1.853
#
# Interval 466 (465000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0180
# 2 episodes - episode_reward: 14.000 [10.000, 18.000] - loss: 0.011 - mae: 1.649 - mean_q: 1.988 - mean_eps: 0.100 - ale.lives: 1.843
#
# Interval 467 (466000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0230
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.011 - mae: 1.666 - mean_q: 2.009 - mean_eps: 0.100 - ale.lives: 2.243
#
# Interval 468 (467000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0260
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - loss: 0.011 - mae: 1.648 - mean_q: 1.988 - mean_eps: 0.100 - ale.lives: 2.125
#
# Interval 469 (468000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0200
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - loss: 0.011 - mae: 1.666 - mean_q: 2.009 - mean_eps: 0.100 - ale.lives: 1.789
#
# Interval 470 (469000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0160
# 2 episodes - episode_reward: 11.000 [10.000, 12.000] - loss: 0.012 - mae: 1.669 - mean_q: 2.012 - mean_eps: 0.100 - ale.lives: 1.862
#
# Interval 471 (470000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0230
# 2 episodes - episode_reward: 11.500 [6.000, 17.000] - loss: 0.011 - mae: 1.681 - mean_q: 2.029 - mean_eps: 0.100 - ale.lives: 1.730
#
# Interval 472 (471000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0230
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.011 - mae: 1.684 - mean_q: 2.030 - mean_eps: 0.100 - ale.lives: 2.424
#
# Interval 473 (472000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0270
# 2 episodes - episode_reward: 13.000 [11.000, 15.000] - loss: 0.012 - mae: 1.683 - mean_q: 2.029 - mean_eps: 0.100 - ale.lives: 2.100
#
# Interval 474 (473000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0260
# Interval 475 (474000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0210
# 2 episodes - episode_reward: 24.000 [14.000, 34.000] - loss: 0.011 - mae: 1.678 - mean_q: 2.025 - mean_eps: 0.100 - ale.lives: 2.387
#
# Interval 476 (475000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.012 - mae: 1.685 - mean_q: 2.032 - mean_eps: 0.100 - ale.lives: 2.645
#
# Interval 477 (476000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0210
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.012 - mae: 1.684 - mean_q: 2.029 - mean_eps: 0.100 - ale.lives: 1.700
#
# Interval 478 (477000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0180
# Interval 479 (478000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0270
# 2 episodes - episode_reward: 21.500 [19.000, 24.000] - loss: 0.011 - mae: 1.676 - mean_q: 2.019 - mean_eps: 0.100 - ale.lives: 2.326
#
# Interval 480 (479000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0220
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.011 - mae: 1.672 - mean_q: 2.014 - mean_eps: 0.100 - ale.lives: 1.965
#
# Interval 481 (480000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0280
# 2 episodes - episode_reward: 13.000 [10.000, 16.000] - loss: 0.012 - mae: 1.681 - mean_q: 2.027 - mean_eps: 0.100 - ale.lives: 2.258
#
# Interval 482 (481000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0100
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.012 - mae: 1.693 - mean_q: 2.040 - mean_eps: 0.100 - ale.lives: 2.127
#
# Interval 483 (482000 steps performed)
# 1000/1000 [==============================] - 22s 22ms/step - reward: 0.0120
# 2 episodes - episode_reward: 6.000 [2.000, 10.000] - loss: 0.011 - mae: 1.681 - mean_q: 2.028 - mean_eps: 0.100 - ale.lives: 1.826
#
# Interval 484 (483000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0270
# 2 episodes - episode_reward: 10.500 [5.000, 16.000] - loss: 0.010 - mae: 1.677 - mean_q: 2.023 - mean_eps: 0.100 - ale.lives: 2.192
#
# Interval 485 (484000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0170
# 2 episodes - episode_reward: 13.500 [12.000, 15.000] - loss: 0.010 - mae: 1.681 - mean_q: 2.027 - mean_eps: 0.100 - ale.lives: 2.040
#
# Interval 486 (485000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0240
# 2 episodes - episode_reward: 10.000 [7.000, 13.000] - loss: 0.010 - mae: 1.680 - mean_q: 2.026 - mean_eps: 0.100 - ale.lives: 2.095
#
# Interval 487 (486000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0230
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - loss: 0.011 - mae: 1.679 - mean_q: 2.025 - mean_eps: 0.100 - ale.lives: 1.145
#
# Interval 488 (487000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0270
# Interval 489 (488000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0210
# 2 episodes - episode_reward: 23.000 [19.000, 27.000] - loss: 0.012 - mae: 1.690 - mean_q: 2.039 - mean_eps: 0.100 - ale.lives: 1.727
#
# Interval 490 (489000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0240
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.009 - mae: 1.671 - mean_q: 2.016 - mean_eps: 0.100 - ale.lives: 2.346
#
# Interval 491 (490000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0210
# 2 episodes - episode_reward: 14.000 [12.000, 16.000] - loss: 0.011 - mae: 1.688 - mean_q: 2.036 - mean_eps: 0.100 - ale.lives: 2.034
#
# Interval 492 (491000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0180
# 2 episodes - episode_reward: 10.500 [8.000, 13.000] - loss: 0.011 - mae: 1.688 - mean_q: 2.038 - mean_eps: 0.100 - ale.lives: 2.070
#
# Interval 493 (492000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0240
# Interval 494 (493000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0230
# 1 episodes - episode_reward: 29.000 [29.000, 29.000] - loss: 0.012 - mae: 1.683 - mean_q: 2.030 - mean_eps: 0.100 - ale.lives: 1.857
#
# Interval 495 (494000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 2 episodes - episode_reward: 21.000 [17.000, 25.000] - loss: 0.010 - mae: 1.695 - mean_q: 2.045 - mean_eps: 0.100 - ale.lives: 1.608
#
# Interval 496 (495000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0190
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.011 - mae: 1.697 - mean_q: 2.045 - mean_eps: 0.100 - ale.lives: 1.999
#
# Interval 497 (496000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0240
# Interval 498 (497000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0160
# 2 episodes - episode_reward: 18.000 [12.000, 24.000] - loss: 0.010 - mae: 1.687 - mean_q: 2.035 - mean_eps: 0.100 - ale.lives: 1.792
#
# Interval 499 (498000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0260
# 2 episodes - episode_reward: 12.500 [6.000, 19.000] - loss: 0.011 - mae: 1.680 - mean_q: 2.026 - mean_eps: 0.100 - ale.lives: 1.990
#
# Interval 500 (499000 steps performed)
# 1000/1000 [==============================] - 21s 20ms/step - reward: 0.0240
# done, took 8040.519 seconds

# %%
# Testing part to calculate the mean reward
weights_filename = 'dqn3_{}_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
results = dqn.test(env, nb_episodes=10, visualize=True)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 24.000, steps: 914
# Episode 2: reward: 16.000, steps: 699
# Episode 3: reward: 18.000, steps: 948
# Episode 4: reward: 25.000, steps: 931
# Episode 5: reward: 12.000, steps: 464
# Episode 6: reward: 16.000, steps: 620
# Episode 7: reward: 22.000, steps: 819
# Episode 8: reward: 13.000, steps: 669
# Episode 9: reward: 9.000, steps: 482
# Episode 10: reward: 14.000, steps: 506

# %%
print(f"Average reward: {np.mean(results.history['episode_reward']):.1f}")
# Out:
# Average reward: 16.9

# %%
weights_filename
# Out:
# 'dqn3_SpaceInvaders-v0_weights.h5f'

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %% [markdown]
# ---

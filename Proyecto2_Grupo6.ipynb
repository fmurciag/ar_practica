# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 2-3 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1: José Jesús La Casa Nieto
# *   Alumno 2:
# *   Alumno 3:

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/08_MIAR/actividades/proyecto practico"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())
# Out:
# Archivos en el directorio:
# ['checkpoint', 'dqn_SpaceInvaders-v0_log.json', 'dqn_SpaceInvaders-v0_weights.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights.h5f.index', 'dqn_SpaceInvaders-v0_weights_250000.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights_250000.h5f.index', 'dqn_SpaceInvaders-v0_weights_500000.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights_500000.h5f.index', 'Proyecto2_Grupo6.ipynb', 'Proyecto_Grupo6.ipynb', 'Proyecto_práctico.ipynb']

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install tensorflow==2.8
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.5.3
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN
# 3.   Justificar la respuesta en relación a los resultados obtenidos
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %%
print("Número de acciones disponibles: " + str(nb_actions))
# Out:
# Número de acciones disponibles: 6

# %%
print("Formato de observaciones:", env.observation_space)
# Out:
# Formato de observaciones: Box(0, 255, (210, 160, 3), uint8)

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()
print(K.image_data_format())

if K.image_data_format() == 'channels_last':
    model.add(Permute((2, 3, 1), input_shape=input_shape))
elif K.image_data_format() == 'channels_first':
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')

model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('linear'))
print(model.summary())
# Out:
# channels_last
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute (Permute)            (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 20, 20, 32)        8224
# _________________________________________________________________
# activation (Activation)      (None, 20, 20, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 9, 64)          32832
# _________________________________________________________________
# activation_1 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1606144
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 1542
# _________________________________________________________________
# activation_5 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 1,816,998
# Trainable params: 1,816,998
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# 2. Implementación de la solución DQN

# %%
memory = SequentialMemory(limit=100000, window_length=WINDOW_LENGTH)    # Reduzco un poco la memoria
processor = AtariProcessor()

# %%
policy = LinearAnnealedPolicy(
    EpsGreedyQPolicy(),
    attr='eps',
    value_max=1.,
    value_min=.1,
    value_test=.2,
    nb_steps=100000
)

# %%
dqn = DQNAgent(
    model=model,
    nb_actions=nb_actions,
    policy=policy,
    memory=memory,
    processor=processor,
    nb_steps_warmup=100000,   # Aumento el número de pasos iniciales porque el entorno es complejo y así obtiene una base sólida de experiencias
    gamma=.99,
    target_model_update=10000,  # Mantengo las mismas actualizaciones de las redes. Valores altos suponen mayor estabilidad pero más tiempo de entrenamiento
    train_interval=4,
    enable_dueling_network=True,
    dueling_type='avg'
)
dqn.compile(Adam(learning_rate=.00025), metrics=['mae'])

# %%
# Train
weights_filename = 'dqn2_{}_weights.h5f'.format(env_name)
checkpoint_weights_filename = 'dqn2_' + env_name + '_weights_{step}.h5f'
log_filename = 'dqn2_{}_log.json'.format(env_name)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
callbacks += [FileLogger(log_filename, interval=100)]

dqn.fit(
    env,
    callbacks=callbacks,
    nb_steps=500000,
    log_interval=1000,
    visualize=False
)

dqn.save_weights(weights_filename, overwrite=True)
# Out:
# Training for 500000 steps ...
# Interval 1 (0 steps performed)
# c:\Users\pepel\.conda\envs\Miar2_rl38\lib\site-packages\tensorflow\python\keras\engine\training.py:2424: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 1000/1000 [==============================] - 7s 3ms/step - reward: 0.0120
# 2 episodes - episode_reward: 6.000 [6.000, 6.000] - ale.lives: 2.233
#
# Interval 2 (1000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 2 episodes - episode_reward: 7.000 [6.000, 8.000] - ale.lives: 2.224
#
# Interval 3 (2000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - ale.lives: 2.336
#
# Interval 4 (3000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0130
# 2 episodes - episode_reward: 7.000 [7.000, 7.000] - ale.lives: 2.016
#
# Interval 5 (4000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 3 episodes - episode_reward: 6.667 [5.000, 8.000] - ale.lives: 2.129
#
# Interval 6 (5000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0130
# 2 episodes - episode_reward: 6.000 [4.000, 8.000] - ale.lives: 2.353
#
# Interval 7 (6000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0100
# 2 episodes - episode_reward: 5.500 [5.000, 6.000] - ale.lives: 2.084
#
# Interval 8 (7000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0110
# 1 episodes - episode_reward: 5.000 [5.000, 5.000] - ale.lives: 2.210
#
# Interval 9 (8000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 2 episodes - episode_reward: 8.500 [5.000, 12.000] - ale.lives: 2.147
#
# Interval 10 (9000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0110
# 2 episodes - episode_reward: 5.500 [5.000, 6.000] - ale.lives: 2.240
#
# Interval 11 (10000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0130
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - ale.lives: 1.815
#
# Interval 12 (11000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 2 episodes - episode_reward: 10.000 [7.000, 13.000] - ale.lives: 2.176
#
# Interval 13 (12000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0160
# 2 episodes - episode_reward: 9.000 [7.000, 11.000] - ale.lives: 1.848
#
# Interval 14 (13000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0160
# 2 episodes - episode_reward: 8.000 [6.000, 10.000] - ale.lives: 1.972
#
# Interval 15 (14000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0230
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - ale.lives: 2.450
#
# Interval 16 (15000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0130
# 2 episodes - episode_reward: 9.000 [9.000, 9.000] - ale.lives: 1.867
#
# Interval 17 (16000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0190
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - ale.lives: 2.022
#
# Interval 18 (17000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0250
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - ale.lives: 2.274
#
# Interval 19 (18000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0160
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 2.138
#
# Interval 20 (19000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0210
# 2 episodes - episode_reward: 12.500 [5.000, 20.000] - ale.lives: 2.284
#
# Interval 21 (20000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0110
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - ale.lives: 1.897
#
# Interval 22 (21000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - ale.lives: 2.201
#
# Interval 23 (22000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# Interval 24 (23000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 2 episodes - episode_reward: 14.500 [10.000, 19.000] - ale.lives: 2.527
#
# Interval 25 (24000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0160
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - ale.lives: 1.717
#
# Interval 26 (25000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0160
# 2 episodes - episode_reward: 9.000 [7.000, 11.000] - ale.lives: 1.931
#
# Interval 27 (26000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - ale.lives: 1.590
#
# Interval 28 (27000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0140
# 2 episodes - episode_reward: 8.000 [3.000, 13.000] - ale.lives: 1.898
#
# Interval 29 (28000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 1 episodes - episode_reward: 9.000 [9.000, 9.000] - ale.lives: 2.169
#
# Interval 30 (29000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 2 episodes - episode_reward: 11.000 [8.000, 14.000] - ale.lives: 2.051
#
# Interval 31 (30000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - ale.lives: 2.198
#
# Interval 32 (31000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0120
# 2 episodes - episode_reward: 9.500 [8.000, 11.000] - ale.lives: 1.883
#
# Interval 33 (32000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0250
# 1 episodes - episode_reward: 25.000 [25.000, 25.000] - ale.lives: 2.064
#
# Interval 34 (33000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 1 episodes - episode_reward: 4.000 [4.000, 4.000] - ale.lives: 1.959
#
# Interval 35 (34000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0230
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - ale.lives: 1.599
#
# Interval 36 (35000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - ale.lives: 2.421
#
# Interval 37 (36000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 1.807
#
# Interval 38 (37000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0140
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - ale.lives: 1.497
#
# Interval 39 (38000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0160
# 2 episodes - episode_reward: 14.000 [13.000, 15.000] - ale.lives: 2.226
#
# Interval 40 (39000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0110
# 2 episodes - episode_reward: 3.000 [3.000, 3.000] - ale.lives: 2.076
#
# Interval 41 (40000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 2 episodes - episode_reward: 12.500 [6.000, 19.000] - ale.lives: 2.373
#
# Interval 42 (41000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0250
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - ale.lives: 1.904
#
# Interval 43 (42000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 2 episodes - episode_reward: 12.500 [6.000, 19.000] - ale.lives: 2.044
#
# Interval 44 (43000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0130
# 2 episodes - episode_reward: 10.000 [5.000, 15.000] - ale.lives: 1.681
#
# Interval 45 (44000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0250
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - ale.lives: 2.080
#
# Interval 46 (45000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 1 episodes - episode_reward: 8.000 [8.000, 8.000] - ale.lives: 2.071
#
# Interval 47 (46000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 2 episodes - episode_reward: 10.500 [6.000, 15.000] - ale.lives: 2.053
#
# Interval 48 (47000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0260
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - ale.lives: 1.889
#
# Interval 49 (48000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0100
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - ale.lives: 1.921
#
# Interval 50 (49000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0180
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - ale.lives: 2.066
#
# Interval 51 (50000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 1 episodes - episode_reward: 9.000 [9.000, 9.000] - ale.lives: 1.489
#
# Interval 52 (51000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 2 episodes - episode_reward: 10.000 [10.000, 10.000] - ale.lives: 2.173
#
# Interval 53 (52000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0110
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 2.274
#
# Interval 54 (53000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 8.000 [8.000, 8.000] - ale.lives: 1.399
#
# Interval 55 (54000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 2 episodes - episode_reward: 14.500 [11.000, 18.000] - ale.lives: 2.157
#
# Interval 56 (55000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0220
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - ale.lives: 1.865
#
# Interval 57 (56000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0270
# 2 episodes - episode_reward: 13.500 [12.000, 15.000] - ale.lives: 2.309
#
# Interval 58 (57000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 2 episodes - episode_reward: 14.000 [10.000, 18.000] - ale.lives: 2.001
#
# Interval 59 (58000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - ale.lives: 1.936
#
# Interval 60 (59000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 2 episodes - episode_reward: 9.500 [6.000, 13.000] - ale.lives: 1.893
#
# Interval 61 (60000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0140
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 1.823
#
# Interval 62 (61000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 1 episodes - episode_reward: 8.000 [8.000, 8.000] - ale.lives: 1.695
#
# Interval 63 (62000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - ale.lives: 1.822
#
# Interval 64 (63000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0240
# 2 episodes - episode_reward: 16.500 [16.000, 17.000] - ale.lives: 2.113
#
# Interval 65 (64000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0110
# Interval 66 (65000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 2 episodes - episode_reward: 19.500 [15.000, 24.000] - ale.lives: 1.996
#
# Interval 67 (66000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 1 episodes - episode_reward: 5.000 [5.000, 5.000] - ale.lives: 2.179
#
# Interval 68 (67000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0180
# 2 episodes - episode_reward: 11.500 [11.000, 12.000] - ale.lives: 1.965
#
# Interval 69 (68000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 2 episodes - episode_reward: 13.000 [11.000, 15.000] - ale.lives: 1.537
#
# Interval 70 (69000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0170
# 2 episodes - episode_reward: 5.500 [5.000, 6.000] - ale.lives: 2.257
#
# Interval 71 (70000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - ale.lives: 2.048
#
# Interval 72 (71000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0260
# 1 episodes - episode_reward: 27.000 [27.000, 27.000] - ale.lives: 1.626
#
# Interval 73 (72000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0180
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 1.816
#
# Interval 74 (73000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0070
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - ale.lives: 1.886
#
# Interval 75 (74000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - ale.lives: 2.044
#
# Interval 76 (75000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 1.745
#
# Interval 77 (76000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0210
# 2 episodes - episode_reward: 11.500 [9.000, 14.000] - ale.lives: 2.195
#
# Interval 78 (77000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - ale.lives: 1.888
#
# Interval 79 (78000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 2 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 2.248
#
# Interval 80 (79000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0190
# 2 episodes - episode_reward: 11.000 [6.000, 16.000] - ale.lives: 1.655
#
# Interval 81 (80000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - ale.lives: 1.818
#
# Interval 82 (81000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0180
# 1 episodes - episode_reward: 4.000 [4.000, 4.000] - ale.lives: 2.111
#
# Interval 83 (82000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0130
# 2 episodes - episode_reward: 14.500 [9.000, 20.000] - ale.lives: 2.108
#
# Interval 84 (83000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 7.000 [7.000, 7.000] - ale.lives: 1.417
#
# Interval 85 (84000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 1.849
#
# Interval 86 (85000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0180
# 2 episodes - episode_reward: 19.000 [17.000, 21.000] - ale.lives: 1.676
#
# Interval 87 (86000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0160
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 1.860
#
# Interval 88 (87000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# Interval 89 (88000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0140
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - ale.lives: 2.092
#
# Interval 90 (89000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 2 episodes - episode_reward: 14.500 [13.000, 16.000] - ale.lives: 1.906
#
# Interval 91 (90000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 1.560
#
# Interval 92 (91000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0110
# 1 episodes - episode_reward: 9.000 [9.000, 9.000] - ale.lives: 1.995
#
# Interval 93 (92000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0200
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - ale.lives: 2.007
#
# Interval 94 (93000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0170
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - ale.lives: 2.063
#
# Interval 95 (94000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0150
# 2 episodes - episode_reward: 10.500 [10.000, 11.000] - ale.lives: 2.288
#
# Interval 96 (95000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0210
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - ale.lives: 1.755
#
# Interval 97 (96000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0250
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - ale.lives: 1.916
#
# Interval 98 (97000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0180
# 2 episodes - episode_reward: 17.000 [17.000, 17.000] - ale.lives: 2.074
#
# Interval 99 (98000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: 0.0160
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - ale.lives: 2.160
#
# Interval 100 (99000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: 0.0160
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - ale.lives: 2.243
#
# Interval 101 (100000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0170
# 2 episodes - episode_reward: 12.000 [11.000, 13.000] - loss: 0.009 - mae: 0.025 - mean_q: 0.039 - mean_eps: 0.100 - ale.lives: 1.795
#
# Interval 102 (101000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0140
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.009 - mae: 0.027 - mean_q: 0.034 - mean_eps: 0.100 - ale.lives: 1.878
#
# Interval 103 (102000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0150
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.007 - mae: 0.023 - mean_q: 0.028 - mean_eps: 0.100 - ale.lives: 1.737
#
# Interval 104 (103000 steps performed)
# 1000/1000 [==============================] - 15s 15ms/step - reward: 0.0180
# 2 episodes - episode_reward: 9.000 [9.000, 9.000] - loss: 0.008 - mae: 0.024 - mean_q: 0.029 - mean_eps: 0.100 - ale.lives: 1.918
#
# Interval 105 (104000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0190
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - loss: 0.008 - mae: 0.025 - mean_q: 0.031 - mean_eps: 0.100 - ale.lives: 2.125
#
# Interval 106 (105000 steps performed)
# 1000/1000 [==============================] - 18s 17ms/step - reward: 0.0120
# 2 episodes - episode_reward: 9.000 [7.000, 11.000] - loss: 0.009 - mae: 0.027 - mean_q: 0.034 - mean_eps: 0.100 - ale.lives: 2.349
#
# Interval 107 (106000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0180
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.009 - mae: 0.027 - mean_q: 0.035 - mean_eps: 0.100 - ale.lives: 2.007
#
# Interval 108 (107000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0210
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.009 - mae: 0.027 - mean_q: 0.035 - mean_eps: 0.100 - ale.lives: 2.426
#
# Interval 109 (108000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0260
# 1 episodes - episode_reward: 33.000 [33.000, 33.000] - loss: 0.009 - mae: 0.025 - mean_q: 0.031 - mean_eps: 0.100 - ale.lives: 1.895
#
# Interval 110 (109000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0190
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.009 - mae: 0.028 - mean_q: 0.035 - mean_eps: 0.100 - ale.lives: 2.356
#
# Interval 111 (110000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0180
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.010 - mae: 0.047 - mean_q: 0.059 - mean_eps: 0.100 - ale.lives: 2.048
#
# Interval 112 (111000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 2 episodes - episode_reward: 14.500 [13.000, 16.000] - loss: 0.008 - mae: 0.048 - mean_q: 0.061 - mean_eps: 0.100 - ale.lives: 1.947
#
# Interval 113 (112000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - loss: 0.009 - mae: 0.048 - mean_q: 0.059 - mean_eps: 0.100 - ale.lives: 2.139
#
# Interval 114 (113000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0230
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.008 - mae: 0.047 - mean_q: 0.058 - mean_eps: 0.100 - ale.lives: 2.029
#
# Interval 115 (114000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.008 - mae: 0.046 - mean_q: 0.057 - mean_eps: 0.100 - ale.lives: 2.605
#
# Interval 116 (115000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.011 - mae: 0.053 - mean_q: 0.065 - mean_eps: 0.100 - ale.lives: 2.194
#
# Interval 117 (116000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0170
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.008 - mae: 0.045 - mean_q: 0.057 - mean_eps: 0.100 - ale.lives: 1.783
#
# Interval 118 (117000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0150
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - loss: 0.008 - mae: 0.046 - mean_q: 0.058 - mean_eps: 0.100 - ale.lives: 1.882
#
# Interval 119 (118000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0200
# 2 episodes - episode_reward: 12.500 [9.000, 16.000] - loss: 0.009 - mae: 0.049 - mean_q: 0.062 - mean_eps: 0.100 - ale.lives: 2.116
#
# Interval 120 (119000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0220
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - loss: 0.009 - mae: 0.050 - mean_q: 0.063 - mean_eps: 0.100 - ale.lives: 1.999
#
# Interval 121 (120000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0050
# 1 episodes - episode_reward: 10.000 [10.000, 10.000] - loss: 0.009 - mae: 0.064 - mean_q: 0.078 - mean_eps: 0.100 - ale.lives: 1.807
#
# Interval 122 (121000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# Interval 123 (122000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0130
# 2 episodes - episode_reward: 12.500 [9.000, 16.000] - loss: 0.009 - mae: 0.067 - mean_q: 0.081 - mean_eps: 0.100 - ale.lives: 2.135
#
# Interval 124 (123000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0190
# 1 episodes - episode_reward: 5.000 [5.000, 5.000] - loss: 0.008 - mae: 0.065 - mean_q: 0.082 - mean_eps: 0.100 - ale.lives: 2.625
#
# Interval 125 (124000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0170
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - loss: 0.008 - mae: 0.066 - mean_q: 0.081 - mean_eps: 0.100 - ale.lives: 1.936
#
# Interval 126 (125000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.009 - mae: 0.067 - mean_q: 0.082 - mean_eps: 0.100 - ale.lives: 2.565
#
# Interval 127 (126000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 2 episodes - episode_reward: 16.500 [7.000, 26.000] - loss: 0.009 - mae: 0.067 - mean_q: 0.082 - mean_eps: 0.100 - ale.lives: 1.910
#
# Interval 128 (127000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 2 episodes - episode_reward: 8.500 [5.000, 12.000] - loss: 0.008 - mae: 0.064 - mean_q: 0.079 - mean_eps: 0.100 - ale.lives: 1.925
#
# Interval 129 (128000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0280
# Interval 130 (129000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0200
# 1 episodes - episode_reward: 29.000 [29.000, 29.000] - loss: 0.009 - mae: 0.066 - mean_q: 0.081 - mean_eps: 0.100 - ale.lives: 2.243
#
# Interval 131 (130000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 2 episodes - episode_reward: 17.000 [11.000, 23.000] - loss: 0.009 - mae: 0.091 - mean_q: 0.113 - mean_eps: 0.100 - ale.lives: 1.634
#
# Interval 132 (131000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0130
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - loss: 0.008 - mae: 0.092 - mean_q: 0.116 - mean_eps: 0.100 - ale.lives: 1.819
#
# Interval 133 (132000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 1 episodes - episode_reward: 9.000 [9.000, 9.000] - loss: 0.008 - mae: 0.093 - mean_q: 0.116 - mean_eps: 0.100 - ale.lives: 1.933
#
# Interval 134 (133000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0230
# 2 episodes - episode_reward: 16.500 [15.000, 18.000] - loss: 0.008 - mae: 0.092 - mean_q: 0.115 - mean_eps: 0.100 - ale.lives: 2.278
#
# Interval 135 (134000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - loss: 0.009 - mae: 0.093 - mean_q: 0.116 - mean_eps: 0.100 - ale.lives: 1.763
#
# Interval 136 (135000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0250
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.009 - mae: 0.092 - mean_q: 0.114 - mean_eps: 0.100 - ale.lives: 1.785
#
# Interval 137 (136000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0190
# 2 episodes - episode_reward: 12.000 [5.000, 19.000] - loss: 0.009 - mae: 0.094 - mean_q: 0.116 - mean_eps: 0.100 - ale.lives: 2.405
#
# Interval 138 (137000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0100
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.009 - mae: 0.094 - mean_q: 0.117 - mean_eps: 0.100 - ale.lives: 1.737
#
# Interval 139 (138000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0200
# 2 episodes - episode_reward: 12.000 [6.000, 18.000] - loss: 0.010 - mae: 0.096 - mean_q: 0.118 - mean_eps: 0.100 - ale.lives: 1.919
#
# Interval 140 (139000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - loss: 0.009 - mae: 0.095 - mean_q: 0.118 - mean_eps: 0.100 - ale.lives: 2.300
#
# Interval 141 (140000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0130
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.008 - mae: 0.119 - mean_q: 0.147 - mean_eps: 0.100 - ale.lives: 2.154
#
# Interval 142 (141000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0200
# 2 episodes - episode_reward: 10.000 [5.000, 15.000] - loss: 0.008 - mae: 0.123 - mean_q: 0.149 - mean_eps: 0.100 - ale.lives: 1.897
#
# Interval 143 (142000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0170
# 2 episodes - episode_reward: 10.000 [5.000, 15.000] - loss: 0.009 - mae: 0.126 - mean_q: 0.155 - mean_eps: 0.100 - ale.lives: 1.880
#
# Interval 144 (143000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - loss: 0.009 - mae: 0.125 - mean_q: 0.155 - mean_eps: 0.100 - ale.lives: 1.942
#
# Interval 145 (144000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0150
# 2 episodes - episode_reward: 11.500 [11.000, 12.000] - loss: 0.009 - mae: 0.125 - mean_q: 0.154 - mean_eps: 0.100 - ale.lives: 2.261
#
# Interval 146 (145000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0190
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - loss: 0.008 - mae: 0.123 - mean_q: 0.151 - mean_eps: 0.100 - ale.lives: 2.514
#
# Interval 147 (146000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0140
# 2 episodes - episode_reward: 11.000 [9.000, 13.000] - loss: 0.008 - mae: 0.123 - mean_q: 0.151 - mean_eps: 0.100 - ale.lives: 1.837
#
# Interval 148 (147000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0170
# 2 episodes - episode_reward: 8.500 [5.000, 12.000] - loss: 0.008 - mae: 0.124 - mean_q: 0.151 - mean_eps: 0.100 - ale.lives: 1.783
#
# Interval 149 (148000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.008 - mae: 0.124 - mean_q: 0.150 - mean_eps: 0.100 - ale.lives: 2.997
#
# Interval 150 (149000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0190
# Interval 151 (150000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0140
# 2 episodes - episode_reward: 14.000 [8.000, 20.000] - loss: 0.010 - mae: 0.152 - mean_q: 0.187 - mean_eps: 0.100 - ale.lives: 2.072
#
# Interval 152 (151000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0250
# 1 episodes - episode_reward: 10.000 [10.000, 10.000] - loss: 0.010 - mae: 0.153 - mean_q: 0.189 - mean_eps: 0.100 - ale.lives: 2.015
#
# Interval 153 (152000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0130
# 1 episodes - episode_reward: 32.000 [32.000, 32.000] - loss: 0.009 - mae: 0.152 - mean_q: 0.189 - mean_eps: 0.100 - ale.lives: 1.371
#
# Interval 154 (153000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0280
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.008 - mae: 0.149 - mean_q: 0.184 - mean_eps: 0.100 - ale.lives: 1.932
#
# Interval 155 (154000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0120
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.010 - mae: 0.155 - mean_q: 0.194 - mean_eps: 0.100 - ale.lives: 2.191
#
# Interval 156 (155000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 2 episodes - episode_reward: 10.500 [9.000, 12.000] - loss: 0.008 - mae: 0.150 - mean_q: 0.185 - mean_eps: 0.100 - ale.lives: 2.029
#
# Interval 157 (156000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0140
# 1 episodes - episode_reward: 4.000 [4.000, 4.000] - loss: 0.009 - mae: 0.152 - mean_q: 0.187 - mean_eps: 0.100 - ale.lives: 2.764
#
# Interval 158 (157000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0100
# Interval 159 (158000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 2 episodes - episode_reward: 19.000 [16.000, 22.000] - loss: 0.008 - mae: 0.148 - mean_q: 0.183 - mean_eps: 0.100 - ale.lives: 2.097
#
# Interval 160 (159000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - loss: 0.008 - mae: 0.147 - mean_q: 0.182 - mean_eps: 0.100 - ale.lives: 1.188
#
# Interval 161 (160000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0220
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.009 - mae: 0.179 - mean_q: 0.221 - mean_eps: 0.100 - ale.lives: 2.181
#
# Interval 162 (161000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0250
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.009 - mae: 0.179 - mean_q: 0.221 - mean_eps: 0.100 - ale.lives: 1.921
#
# Interval 163 (162000 steps performed)
# 1000/1000 [==============================] - 17s 16ms/step - reward: 0.0140
# 2 episodes - episode_reward: 16.000 [9.000, 23.000] - loss: 0.008 - mae: 0.180 - mean_q: 0.219 - mean_eps: 0.100 - ale.lives: 2.141
#
# Interval 164 (163000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.010 - mae: 0.182 - mean_q: 0.221 - mean_eps: 0.100 - ale.lives: 1.605
#
# Interval 165 (164000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0220
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - loss: 0.009 - mae: 0.179 - mean_q: 0.220 - mean_eps: 0.100 - ale.lives: 2.193
#
# Interval 166 (165000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0170
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.008 - mae: 0.178 - mean_q: 0.219 - mean_eps: 0.100 - ale.lives: 2.030
#
# Interval 167 (166000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0210
# 1 episodes - episode_reward: 5.000 [5.000, 5.000] - loss: 0.009 - mae: 0.181 - mean_q: 0.221 - mean_eps: 0.100 - ale.lives: 2.283
#
# Interval 168 (167000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0130
# 1 episodes - episode_reward: 25.000 [25.000, 25.000] - loss: 0.008 - mae: 0.175 - mean_q: 0.214 - mean_eps: 0.100 - ale.lives: 1.480
#
# Interval 169 (168000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - loss: 0.008 - mae: 0.175 - mean_q: 0.216 - mean_eps: 0.100 - ale.lives: 1.871
#
# Interval 170 (169000 steps performed)
# 1000/1000 [==============================] - 18s 17ms/step - reward: 0.0160
# 2 episodes - episode_reward: 14.500 [8.000, 21.000] - loss: 0.008 - mae: 0.177 - mean_q: 0.217 - mean_eps: 0.100 - ale.lives: 2.279
#
# Interval 171 (170000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0220
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.010 - mae: 0.206 - mean_q: 0.251 - mean_eps: 0.100 - ale.lives: 2.157
#
# Interval 172 (171000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0140
# 2 episodes - episode_reward: 14.000 [11.000, 17.000] - loss: 0.008 - mae: 0.205 - mean_q: 0.250 - mean_eps: 0.100 - ale.lives: 2.001
#
# Interval 173 (172000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0160
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.009 - mae: 0.205 - mean_q: 0.250 - mean_eps: 0.100 - ale.lives: 2.463
#
# Interval 174 (173000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0260
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.008 - mae: 0.204 - mean_q: 0.251 - mean_eps: 0.100 - ale.lives: 2.373
#
# Interval 175 (174000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0140
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - loss: 0.008 - mae: 0.205 - mean_q: 0.253 - mean_eps: 0.100 - ale.lives: 2.231
#
# Interval 176 (175000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0260
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.008 - mae: 0.203 - mean_q: 0.247 - mean_eps: 0.100 - ale.lives: 2.634
#
# Interval 177 (176000 steps performed)
# 1000/1000 [==============================] - 18s 17ms/step - reward: 0.0130
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.009 - mae: 0.205 - mean_q: 0.249 - mean_eps: 0.100 - ale.lives: 2.010
#
# Interval 178 (177000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0160
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.008 - mae: 0.207 - mean_q: 0.251 - mean_eps: 0.100 - ale.lives: 1.517
#
# Interval 179 (178000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0180
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.009 - mae: 0.209 - mean_q: 0.253 - mean_eps: 0.100 - ale.lives: 1.824
#
# Interval 180 (179000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0160
# 2 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.007 - mae: 0.205 - mean_q: 0.248 - mean_eps: 0.100 - ale.lives: 1.987
#
# Interval 181 (180000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - loss: 0.008 - mae: 0.229 - mean_q: 0.277 - mean_eps: 0.100 - ale.lives: 1.340
#
# Interval 182 (181000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.009 - mae: 0.232 - mean_q: 0.281 - mean_eps: 0.100 - ale.lives: 2.006
#
# Interval 183 (182000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.009 - mae: 0.232 - mean_q: 0.283 - mean_eps: 0.100 - ale.lives: 2.184
#
# Interval 184 (183000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0140
# 1 episodes - episode_reward: 7.000 [7.000, 7.000] - loss: 0.010 - mae: 0.234 - mean_q: 0.283 - mean_eps: 0.100 - ale.lives: 1.886
#
# Interval 185 (184000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0300
# 2 episodes - episode_reward: 14.000 [9.000, 19.000] - loss: 0.008 - mae: 0.234 - mean_q: 0.284 - mean_eps: 0.100 - ale.lives: 2.156
#
# Interval 186 (185000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - loss: 0.009 - mae: 0.235 - mean_q: 0.285 - mean_eps: 0.100 - ale.lives: 2.006
#
# Interval 187 (186000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0130
# 1 episodes - episode_reward: 10.000 [10.000, 10.000] - loss: 0.008 - mae: 0.230 - mean_q: 0.279 - mean_eps: 0.100 - ale.lives: 2.187
#
# Interval 188 (187000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0130
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.008 - mae: 0.230 - mean_q: 0.279 - mean_eps: 0.100 - ale.lives: 1.555
#
# Interval 189 (188000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0270
# 2 episodes - episode_reward: 18.000 [11.000, 25.000] - loss: 0.008 - mae: 0.232 - mean_q: 0.285 - mean_eps: 0.100 - ale.lives: 2.192
#
# Interval 190 (189000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0140
# Interval 191 (190000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0150
# 2 episodes - episode_reward: 11.000 [5.000, 17.000] - loss: 0.008 - mae: 0.263 - mean_q: 0.321 - mean_eps: 0.100 - ale.lives: 2.111
#
# Interval 192 (191000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - loss: 0.010 - mae: 0.266 - mean_q: 0.323 - mean_eps: 0.100 - ale.lives: 1.883
#
# Interval 193 (192000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0250
# 2 episodes - episode_reward: 14.500 [11.000, 18.000] - loss: 0.009 - mae: 0.266 - mean_q: 0.322 - mean_eps: 0.100 - ale.lives: 2.169
#
# Interval 194 (193000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.008 - mae: 0.263 - mean_q: 0.319 - mean_eps: 0.100 - ale.lives: 2.000
#
# Interval 195 (194000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0150
# 2 episodes - episode_reward: 9.500 [8.000, 11.000] - loss: 0.009 - mae: 0.264 - mean_q: 0.321 - mean_eps: 0.100 - ale.lives: 1.923
#
# Interval 196 (195000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0200
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.007 - mae: 0.261 - mean_q: 0.318 - mean_eps: 0.100 - ale.lives: 1.987
#
# Interval 197 (196000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0210
# 1 episodes - episode_reward: 30.000 [30.000, 30.000] - loss: 0.008 - mae: 0.263 - mean_q: 0.321 - mean_eps: 0.100 - ale.lives: 1.309
#
# Interval 198 (197000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - loss: 0.008 - mae: 0.261 - mean_q: 0.316 - mean_eps: 0.100 - ale.lives: 2.078
#
# Interval 199 (198000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.008 - mae: 0.264 - mean_q: 0.319 - mean_eps: 0.100 - ale.lives: 2.063
#
# Interval 200 (199000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0090
# 2 episodes - episode_reward: 5.000 [3.000, 7.000] - loss: 0.009 - mae: 0.263 - mean_q: 0.316 - mean_eps: 0.100 - ale.lives: 2.085
#
# Interval 201 (200000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0190
# 2 episodes - episode_reward: 7.500 [5.000, 10.000] - loss: 0.009 - mae: 0.289 - mean_q: 0.350 - mean_eps: 0.100 - ale.lives: 2.093
#
# Interval 202 (201000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0090
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.009 - mae: 0.284 - mean_q: 0.343 - mean_eps: 0.100 - ale.lives: 2.040
#
# Interval 203 (202000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0210
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - loss: 0.009 - mae: 0.289 - mean_q: 0.352 - mean_eps: 0.100 - ale.lives: 2.262
#
# Interval 204 (203000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0220
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.008 - mae: 0.281 - mean_q: 0.344 - mean_eps: 0.100 - ale.lives: 1.998
#
# Interval 205 (204000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0130
# 3 episodes - episode_reward: 9.333 [5.000, 17.000] - loss: 0.009 - mae: 0.284 - mean_q: 0.346 - mean_eps: 0.100 - ale.lives: 2.003
#
# Interval 206 (205000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0160
# 2 episodes - episode_reward: 5.000 [5.000, 5.000] - loss: 0.009 - mae: 0.285 - mean_q: 0.345 - mean_eps: 0.100 - ale.lives: 2.356
#
# Interval 207 (206000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0230
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.009 - mae: 0.282 - mean_q: 0.342 - mean_eps: 0.100 - ale.lives: 2.534
#
# Interval 208 (207000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0190
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - loss: 0.008 - mae: 0.283 - mean_q: 0.342 - mean_eps: 0.100 - ale.lives: 2.295
#
# Interval 209 (208000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0200
# 2 episodes - episode_reward: 13.500 [12.000, 15.000] - loss: 0.009 - mae: 0.285 - mean_q: 0.346 - mean_eps: 0.100 - ale.lives: 1.913
#
# Interval 210 (209000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0150
# 1 episodes - episode_reward: 7.000 [7.000, 7.000] - loss: 0.008 - mae: 0.286 - mean_q: 0.348 - mean_eps: 0.100 - ale.lives: 2.377
#
# Interval 211 (210000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0190
# 2 episodes - episode_reward: 12.500 [8.000, 17.000] - loss: 0.008 - mae: 0.304 - mean_q: 0.371 - mean_eps: 0.100 - ale.lives: 2.208
#
# Interval 212 (211000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0190
# 2 episodes - episode_reward: 11.000 [9.000, 13.000] - loss: 0.009 - mae: 0.307 - mean_q: 0.374 - mean_eps: 0.100 - ale.lives: 2.248
#
# Interval 213 (212000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0150
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.008 - mae: 0.303 - mean_q: 0.369 - mean_eps: 0.100 - ale.lives: 1.817
#
# Interval 214 (213000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0140
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.008 - mae: 0.303 - mean_q: 0.370 - mean_eps: 0.100 - ale.lives: 1.714
#
# Interval 215 (214000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0220
# 2 episodes - episode_reward: 11.500 [7.000, 16.000] - loss: 0.008 - mae: 0.304 - mean_q: 0.370 - mean_eps: 0.100 - ale.lives: 2.014
#
# Interval 216 (215000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0150
# 2 episodes - episode_reward: 7.000 [5.000, 9.000] - loss: 0.009 - mae: 0.304 - mean_q: 0.372 - mean_eps: 0.100 - ale.lives: 2.157
#
# Interval 217 (216000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0210
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - loss: 0.008 - mae: 0.307 - mean_q: 0.377 - mean_eps: 0.100 - ale.lives: 1.758
#
# Interval 218 (217000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0130
# 2 episodes - episode_reward: 10.000 [5.000, 15.000] - loss: 0.009 - mae: 0.307 - mean_q: 0.373 - mean_eps: 0.100 - ale.lives: 2.214
#
# Interval 219 (218000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0150
# 2 episodes - episode_reward: 9.500 [5.000, 14.000] - loss: 0.008 - mae: 0.305 - mean_q: 0.371 - mean_eps: 0.100 - ale.lives: 1.816
#
# Interval 220 (219000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0220
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.008 - mae: 0.307 - mean_q: 0.372 - mean_eps: 0.100 - ale.lives: 2.246
#
# Interval 221 (220000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0110
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.010 - mae: 0.326 - mean_q: 0.397 - mean_eps: 0.100 - ale.lives: 1.894
#
# Interval 222 (221000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0120
# 1 episodes - episode_reward: 8.000 [8.000, 8.000] - loss: 0.009 - mae: 0.329 - mean_q: 0.401 - mean_eps: 0.100 - ale.lives: 1.861
#
# Interval 223 (222000 steps performed)
# 1000/1000 [==============================] - 17s 17ms/step - reward: 0.0170
# ...
#
# Interval 436 (435000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0230
# 2 episodes - episode_reward: 8.000 [3.000, 13.000] - loss: 0.010 - mae: 0.845 - mean_q: 1.026 - mean_eps: 0.100 - ale.lives: 2.136
#
# Interval 437 (436000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0220
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - loss: 0.011 - mae: 0.850 - mean_q: 1.033 - mean_eps: 0.100 - ale.lives: 1.876
#
# Interval 438 (437000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0290
# 1 episodes - episode_reward: 16.000 [16.000, 16.000] - loss: 0.010 - mae: 0.844 - mean_q: 1.027 - mean_eps: 0.100 - ale.lives: 2.222
#
# Interval 439 (438000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0200
# 1 episodes - episode_reward: 27.000 [27.000, 27.000] - loss: 0.009 - mae: 0.847 - mean_q: 1.030 - mean_eps: 0.100 - ale.lives: 1.683
#
# Interval 440 (439000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0240
# 2 episodes - episode_reward: 14.500 [9.000, 20.000] - loss: 0.010 - mae: 0.845 - mean_q: 1.027 - mean_eps: 0.100 - ale.lives: 2.112
#
# Interval 441 (440000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0300
# 1 episodes - episode_reward: 30.000 [30.000, 30.000] - loss: 0.010 - mae: 0.857 - mean_q: 1.043 - mean_eps: 0.100 - ale.lives: 1.615
#
# Interval 442 (441000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0200
# 1 episodes - episode_reward: 29.000 [29.000, 29.000] - loss: 0.011 - mae: 0.879 - mean_q: 1.067 - mean_eps: 0.100 - ale.lives: 1.770
#
# Interval 443 (442000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0290
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.011 - mae: 0.866 - mean_q: 1.051 - mean_eps: 0.100 - ale.lives: 1.797
#
# Interval 444 (443000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0250
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - loss: 0.010 - mae: 0.866 - mean_q: 1.051 - mean_eps: 0.100 - ale.lives: 2.026
#
# Interval 445 (444000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0130
# 2 episodes - episode_reward: 10.500 [2.000, 19.000] - loss: 0.010 - mae: 0.869 - mean_q: 1.055 - mean_eps: 0.100 - ale.lives: 1.864
#
# Interval 446 (445000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0290
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - loss: 0.010 - mae: 0.865 - mean_q: 1.050 - mean_eps: 0.100 - ale.lives: 1.889
#
# Interval 447 (446000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0200
# 2 episodes - episode_reward: 12.500 [4.000, 21.000] - loss: 0.010 - mae: 0.858 - mean_q: 1.042 - mean_eps: 0.100 - ale.lives: 2.153
#
# Interval 448 (447000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0230
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.011 - mae: 0.858 - mean_q: 1.040 - mean_eps: 0.100 - ale.lives: 1.944
#
# Interval 449 (448000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0170
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - loss: 0.011 - mae: 0.863 - mean_q: 1.048 - mean_eps: 0.100 - ale.lives: 1.710
#
# Interval 450 (449000 steps performed)
# 1000/1000 [==============================] - 22s 21ms/step - reward: 0.0240
# 2 episodes - episode_reward: 19.000 [15.000, 23.000] - loss: 0.009 - mae: 0.860 - mean_q: 1.044 - mean_eps: 0.100 - ale.lives: 2.178
#
# Interval 451 (450000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0270
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - loss: 0.010 - mae: 0.857 - mean_q: 1.044 - mean_eps: 0.100 - ale.lives: 2.340
#
# Interval 452 (451000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0260
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - loss: 0.010 - mae: 0.861 - mean_q: 1.046 - mean_eps: 0.100 - ale.lives: 1.794
#
# Interval 453 (452000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0230
# 2 episodes - episode_reward: 13.000 [10.000, 16.000] - loss: 0.011 - mae: 0.867 - mean_q: 1.052 - mean_eps: 0.100 - ale.lives: 2.627
#
# Interval 454 (453000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0220
# 2 episodes - episode_reward: 17.500 [11.000, 24.000] - loss: 0.010 - mae: 0.865 - mean_q: 1.051 - mean_eps: 0.100 - ale.lives: 1.650
#
# Interval 455 (454000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0210
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - loss: 0.010 - mae: 0.859 - mean_q: 1.043 - mean_eps: 0.100 - ale.lives: 2.185
#
# Interval 456 (455000 steps performed)
# 1000/1000 [==============================] - 20s 19ms/step - reward: 0.0210
# 2 episodes - episode_reward: 5.500 [1.000, 10.000] - loss: 0.009 - mae: 0.859 - mean_q: 1.042 - mean_eps: 0.100 - ale.lives: 2.000
#
# Interval 457 (456000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0190
# 1 episodes - episode_reward: 11.000 [11.000, 11.000] - loss: 0.010 - mae: 0.858 - mean_q: 1.041 - mean_eps: 0.100 - ale.lives: 1.681
#
# Interval 458 (457000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0280
# 2 episodes - episode_reward: 18.000 [16.000, 20.000] - loss: 0.010 - mae: 0.863 - mean_q: 1.047 - mean_eps: 0.100 - ale.lives: 1.995
#
# Interval 459 (458000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0200
# 1 episodes - episode_reward: 29.000 [29.000, 29.000] - loss: 0.011 - mae: 0.866 - mean_q: 1.051 - mean_eps: 0.100 - ale.lives: 1.137
#
# Interval 460 (459000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 2 episodes - episode_reward: 9.500 [7.000, 12.000] - loss: 0.010 - mae: 0.862 - mean_q: 1.046 - mean_eps: 0.100 - ale.lives: 2.090
#
# Interval 461 (460000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0270
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.009 - mae: 0.878 - mean_q: 1.069 - mean_eps: 0.100 - ale.lives: 2.013
#
# Interval 462 (461000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0210
# 1 episodes - episode_reward: 22.000 [22.000, 22.000] - loss: 0.010 - mae: 0.880 - mean_q: 1.070 - mean_eps: 0.100 - ale.lives: 2.042
#
# Interval 463 (462000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0200
# 2 episodes - episode_reward: 10.500 [7.000, 14.000] - loss: 0.011 - mae: 0.886 - mean_q: 1.077 - mean_eps: 0.100 - ale.lives: 2.205
#
# Interval 464 (463000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0240
# 2 episodes - episode_reward: 17.500 [17.000, 18.000] - loss: 0.010 - mae: 0.880 - mean_q: 1.068 - mean_eps: 0.100 - ale.lives: 2.052
#
# Interval 465 (464000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - loss: 0.010 - mae: 0.884 - mean_q: 1.073 - mean_eps: 0.100 - ale.lives: 1.655
#
# Interval 466 (465000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.011 - mae: 0.895 - mean_q: 1.086 - mean_eps: 0.100 - ale.lives: 2.079
#
# Interval 467 (466000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0210
# 2 episodes - episode_reward: 9.000 [8.000, 10.000] - loss: 0.010 - mae: 0.873 - mean_q: 1.063 - mean_eps: 0.100 - ale.lives: 2.162
#
# Interval 468 (467000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0260
# 1 episodes - episode_reward: 18.000 [18.000, 18.000] - loss: 0.009 - mae: 0.877 - mean_q: 1.067 - mean_eps: 0.100 - ale.lives: 1.938
#
# Interval 469 (468000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0260
# 2 episodes - episode_reward: 15.500 [7.000, 24.000] - loss: 0.009 - mae: 0.889 - mean_q: 1.080 - mean_eps: 0.100 - ale.lives: 1.952
#
# Interval 470 (469000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0250
# 1 episodes - episode_reward: 25.000 [25.000, 25.000] - loss: 0.009 - mae: 0.892 - mean_q: 1.082 - mean_eps: 0.100 - ale.lives: 1.634
#
# Interval 471 (470000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0170
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.009 - mae: 0.927 - mean_q: 1.125 - mean_eps: 0.100 - ale.lives: 2.642
#
# Interval 472 (471000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0290
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - loss: 0.010 - mae: 0.923 - mean_q: 1.120 - mean_eps: 0.100 - ale.lives: 2.230
#
# Interval 473 (472000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0250
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - loss: 0.009 - mae: 0.918 - mean_q: 1.117 - mean_eps: 0.100 - ale.lives: 1.972
#
# Interval 474 (473000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0240
# 1 episodes - episode_reward: 24.000 [24.000, 24.000] - loss: 0.010 - mae: 0.919 - mean_q: 1.115 - mean_eps: 0.100 - ale.lives: 1.753
#
# Interval 475 (474000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0180
# 2 episodes - episode_reward: 12.000 [8.000, 16.000] - loss: 0.010 - mae: 0.928 - mean_q: 1.125 - mean_eps: 0.100 - ale.lives: 2.136
#
# Interval 476 (475000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0150
# 1 episodes - episode_reward: 4.000 [4.000, 4.000] - loss: 0.011 - mae: 0.929 - mean_q: 1.124 - mean_eps: 0.100 - ale.lives: 1.937
#
# Interval 477 (476000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0340
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.010 - mae: 0.923 - mean_q: 1.123 - mean_eps: 0.100 - ale.lives: 1.740
#
# Interval 478 (477000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0150
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - loss: 0.010 - mae: 0.932 - mean_q: 1.133 - mean_eps: 0.100 - ale.lives: 1.858
#
# Interval 479 (478000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0250
# 1 episodes - episode_reward: 14.000 [14.000, 14.000] - loss: 0.009 - mae: 0.922 - mean_q: 1.121 - mean_eps: 0.100 - ale.lives: 2.480
#
# Interval 480 (479000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0230
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - loss: 0.010 - mae: 0.922 - mean_q: 1.119 - mean_eps: 0.100 - ale.lives: 1.946
#
# Interval 481 (480000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0140
# 2 episodes - episode_reward: 12.500 [6.000, 19.000] - loss: 0.011 - mae: 0.945 - mean_q: 1.149 - mean_eps: 0.100 - ale.lives: 2.213
#
# Interval 482 (481000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0300
# 1 episodes - episode_reward: 13.000 [13.000, 13.000] - loss: 0.010 - mae: 0.956 - mean_q: 1.160 - mean_eps: 0.100 - ale.lives: 1.480
#
# Interval 483 (482000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0260
# 1 episodes - episode_reward: 28.000 [28.000, 28.000] - loss: 0.010 - mae: 0.947 - mean_q: 1.149 - mean_eps: 0.100 - ale.lives: 1.720
#
# Interval 484 (483000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0280
# 1 episodes - episode_reward: 26.000 [26.000, 26.000] - loss: 0.011 - mae: 0.967 - mean_q: 1.174 - mean_eps: 0.100 - ale.lives: 1.987
#
# Interval 485 (484000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0200
# 2 episodes - episode_reward: 21.000 [14.000, 28.000] - loss: 0.010 - mae: 0.951 - mean_q: 1.154 - mean_eps: 0.100 - ale.lives: 2.038
#
# Interval 486 (485000 steps performed)
# 1000/1000 [==============================] - 19s 18ms/step - reward: 0.0110
# 2 episodes - episode_reward: 4.500 [4.000, 5.000] - loss: 0.010 - mae: 0.952 - mean_q: 1.156 - mean_eps: 0.100 - ale.lives: 2.160
#
# Interval 487 (486000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0220
# 2 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.010 - mae: 0.960 - mean_q: 1.166 - mean_eps: 0.100 - ale.lives: 1.750
#
# Interval 488 (487000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0260
# 1 episodes - episode_reward: 29.000 [29.000, 29.000] - loss: 0.010 - mae: 0.954 - mean_q: 1.159 - mean_eps: 0.100 - ale.lives: 1.501
#
# Interval 489 (488000 steps performed)
# 1000/1000 [==============================] - 19s 19ms/step - reward: 0.0290
# 1 episodes - episode_reward: 12.000 [12.000, 12.000] - loss: 0.011 - mae: 0.959 - mean_q: 1.163 - mean_eps: 0.100 - ale.lives: 1.693
#
# Interval 490 (489000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0250
# 1 episodes - episode_reward: 19.000 [19.000, 19.000] - loss: 0.009 - mae: 0.951 - mean_q: 1.158 - mean_eps: 0.100 - ale.lives: 2.013
#
# Interval 491 (490000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0230
# 2 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.010 - mae: 0.993 - mean_q: 1.206 - mean_eps: 0.100 - ale.lives: 2.119
#
# Interval 492 (491000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0210
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.010 - mae: 0.994 - mean_q: 1.206 - mean_eps: 0.100 - ale.lives: 2.075
#
# Interval 493 (492000 steps performed)
# 1000/1000 [==============================] - 21s 21ms/step - reward: 0.0270
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - loss: 0.011 - mae: 0.993 - mean_q: 1.209 - mean_eps: 0.100 - ale.lives: 1.689
#
# Interval 494 (493000 steps performed)
# 1000/1000 [==============================] - 16s 16ms/step - reward: 0.0220
# 1 episodes - episode_reward: 15.000 [15.000, 15.000] - loss: 0.011 - mae: 0.995 - mean_q: 1.208 - mean_eps: 0.100 - ale.lives: 1.668
#
# Interval 495 (494000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0180
# 2 episodes - episode_reward: 18.500 [18.000, 19.000] - loss: 0.011 - mae: 0.994 - mean_q: 1.204 - mean_eps: 0.100 - ale.lives: 2.275
#
# Interval 496 (495000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0250
# 1 episodes - episode_reward: 23.000 [23.000, 23.000] - loss: 0.011 - mae: 0.998 - mean_q: 1.211 - mean_eps: 0.100 - ale.lives: 2.077
#
# Interval 497 (496000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0240
# 1 episodes - episode_reward: 17.000 [17.000, 17.000] - loss: 0.011 - mae: 0.989 - mean_q: 1.199 - mean_eps: 0.100 - ale.lives: 2.196
#
# Interval 498 (497000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0220
# 1 episodes - episode_reward: 21.000 [21.000, 21.000] - loss: 0.010 - mae: 0.977 - mean_q: 1.186 - mean_eps: 0.100 - ale.lives: 1.755
#
# Interval 499 (498000 steps performed)
# 1000/1000 [==============================] - 18s 18ms/step - reward: 0.0270
# 1 episodes - episode_reward: 20.000 [20.000, 20.000] - loss: 0.009 - mae: 0.990 - mean_q: 1.203 - mean_eps: 0.100 - ale.lives: 2.223
#
# Interval 500 (499000 steps performed)
# 1000/1000 [==============================] - 20s 20ms/step - reward: 0.0230
# done, took 8017.784 seconds

# %%
# Testing part to calculate the mean reward
weights_filename = 'dqn2_{}_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
results = dqn.test(env, nb_episodes=10, visualize=True)
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 25.000, steps: 833
# Episode 2: reward: 23.000, steps: 870
# Episode 3: reward: 16.000, steps: 557
# Episode 4: reward: 27.000, steps: 1049
# Episode 5: reward: 19.000, steps: 655
# Episode 6: reward: 10.000, steps: 419
# Episode 7: reward: 11.000, steps: 603
# Episode 8: reward: 13.000, steps: 550
# Episode 9: reward: 15.000, steps: 648
# Episode 10: reward: 27.000, steps: 937

# %%
print(f"Average reward: {np.mean(results.history['episode_reward']):.1f}")
# Out:
# Average reward: 18.6

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %% [markdown]
# ---
